# %%
# OVERVIEW

# Background: 
# The 1st Round of the NFL Draft is a phenomenon that can make or break a team's next season.
# We will experiment with the theory that if a team did well on Offense and poorly on Defense in the previous season, 
# then they would use their highest pick on a player that can improve their Defense (or vice-versa)

# Goal: Predict whether or not a team will draft an Offensive or Defensive player in the 1st Round of the NFL Draft

# Data Points:
# Independent Variable: What unit for the position each team drafted in the 1st Round (Offense=OFF or Defense=DEF)
# (teams can have multiple 1st round picks)
# Dependent Variable: A team's stats and league-wide rankings for the previous season

# Example:
# Bengals 2020 Draft QB=Offense=OFF - Bengals 2019 total passing yards, total rushing yards, turnovers, points for/against, etc.
# Bengals 2019 Stats - https://www.pro-football-reference.com/teams/cin/2019.htm

# Data Scraped From:
# 1st Round Draft History Data - http://www.drafthistory.com/index.php/rounds/round_1
# Team Stats and Rankings - https://www.pro-football-reference.com

# %%
# IMPORTS
# DataFrame
import pandas as pd

# Web Scraping
from requests import get
from bs4 import BeautifulSoup

# Math
import math

# %%
# CONSTANTS
CURRENT_YEAR = 2020
YEARS = 20
NUM_NEIGHBORS = 5
TEAM_DICT = {'Bengals':'cin','Redskins':'was','Lions':'det','Giants':'nyg','Dolphins':'mia','Chargers':'sdg',
            'Panthers':'car','Cardinals':'crd','Jaguars':'jax','Browns':'cle','Jets':'nyj','Raiders':'rai',
             'Buccaneers':'tam','49ers':'sfo','Broncos':'den','Falcons':'atl','Cowboys':'dal','Eagles':'phi',
             'Vikings':'min','Saints':'nor','Packers':'gnb','Seahawks':'sea','Ravens':'rav','Titans':'oti',
             'Chiefs':'kan','Colts':'clt','Texans':'htx','Bears':'chi','Steelers':'pit','Rams':'ram','Bills':'buf',
             'Patriots':'nwe'}
EMPTY_COLS = ['Off. Rank Ply', 'Off. Rank Y/P', 'Off. Rank Cmp', 'Off. Rank 1stD', 'Off. Rank 1stD', 'Off. Rank Pen',
             'Off. Rank Yds', 'Off. Rank 1stPy', 'Off. Rank #Dr', 'Def. Rank Ply', 'Def. Rank Y/P', 'Def. Rank Cmp',
             'Def. Rank 1stD', 'Def. Rank 1stD', 'Def. Rank Pen', 'Def. Rank Yds', 'Def. Rank 1stPy', 'Def. Rank #Dr',
             'Off. Rank 1stD.1', 'Off. Rank 1stD.2', 'Off. Rank Yds.3', 'Def. Rank 1stD.1', 'Def. Rank 1stD.2', 'Def. Rank Yds.3']
UNIT_DICT = {'QB':'OFF','RB':'OFF','WR':'OFF','TE':'OFF',' C':'OFF',' G':'OFF',' T':'OFF','DT':'DEF','DE':'DEF','LB':'DEF',
             'DB':'DEF'}
BASIC_FACTORS = ['Position Drafted', 'Team', 'Draft Year', 'Pick Number']
TEAM_FACTORS = ['Team PF', 'Team TO', 'Team Att', 'Team Yds.1', 'Team TD', 'Team Int', 'Team Att.1', 'Team Yds.2', 'Team TD.1', 'Team Y/A', 'Team 1stD.2']
OPP_FACTORS = ['Opp. PF', 'Opp. TO', 'Opp. Att', 'Opp. Yds.1', 'Opp. TD', 'Opp. Int', 'Opp. Att.1', 'Opp. Yds.2', 'Opp. TD.1', 'Opp. Y/A', 'Opp. 1stD.2']
OFF_RANK_FACTORS = ['Off. Rank PF', 'Off. Rank Yds.1', 'Off. Rank TO', 'Off. Rank Att']
DEF_RANK_FACTORS = ['Def. Rank PF', 'Def. Rank Yds.1', 'Def. Rank TO', 'Def. Rank Att']
NEXT_DRAFT_ORDER = ['Jaguars', 'Jets', 'Dolphins', 'Falcons', 'Bengals', 'Eagles', 'Lions', 'Giants', 'Panthers', 'Broncos', 
                    'Cowboys', 'Chargers', 'Vikings', 'Patriots', '49ers', 'Raiders', 'Cardinals', 'Colts', 'Redskins', 'Bears', 
                    'Rams', 'Browns', 'Dolphins', 'Ravens', 'Titans', 'Buccaneers', 'Jets', 'Steelers',
                    'Saints', 'Bills', 'Packers', 'Chiefs']

# %%
# WEB SCRAPING FUNCTIONS
def get_past_first_rounders() -> 'DataFrame':
    url = 'http://www.drafthistory.com/index.php/rounds/round_1'
    response = get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    table = soup.find(id='main')
    row_containers = table.table.find_all('tr')
    row_containers = row_containers[2:]
    labels = ['Year','Round','Pick','Player','Name','Team','Position','College']
    
    all_rows = []
    should_break = False
    for i in row_containers:
        new_row = []
        cols = i.find_all('td')
        for j in range(0, len(cols)):
            if j == 0:
                try:
                    year = int(cols[j].text)
                    if year == CURRENT_YEAR - YEARS:
                        should_break=True
                        break
                    new_row.append(cols[j].text)
                except:
                    new_row.append(year)
            else:
                new_row.append(cols[j].text)
        if should_break:
            break
        if new_row:
            all_rows.append(new_row)
    
    df = pd.DataFrame(all_rows,columns=labels)
    df.drop(columns=['Round','Player','College'], inplace=True)
    return df

def get_team_stats_by_year_url(team_name: str, year) -> str:
    base_url = 'https://www.pro-football-reference.com/teams/'
    end_url = '.htm'
    try: 
        team_id = TEAM_DICT[team_name]
    except:
        team_id = team_name
    return base_url + team_id + '/' + str(year) + end_url

def get_team_stats(url) -> 'DataFrame':
    response = get(url)
    if response.status_code == 404:
        return pd.DataFrame()
    soup = BeautifulSoup(response.text,'html.parser')
    table_container = soup.find(id='all_team_stats')
    if table_container:
        print('Scraping', url)
    else:
        print(url)
    table = table_container.find(class_='table_outer_container').div.table
    
    label_containers = table.thead.find_all('tr')[1].find_all('th')
    labels = []
    for i in label_containers:
        labels.append(str(i.text))
        
    list_of_rows = []
    row_containers = table.tbody.find_all('tr')
    for i in row_containers:
        row = []
        row.append(i.th)
        stat_containers = i.find_all('td')
        for j in stat_containers:
            try: 
                num = float(j.text)
                row.append(num)
            except:
                row.append(str(j.text).strip())
        list_of_rows.append(row)
    
    return pd.DataFrame(list_of_rows,columns=labels)

def convert_team_stats_to_one_row(df) -> 'DataFrame':
    team_columns = []
    opp_columns = []
    off_rank_columns = []
    def_rank_columns = []
    
    for i in df.columns:
        team_columns.append('Team ' + i)
        opp_columns.append('Opp. ' + i)
        off_rank_columns.append('Off. Rank ' + i)
        def_rank_columns.append('Def. Rank ' + i)
        
    row1 = pd.DataFrame([list(df.loc[0])], columns=team_columns)
    row2 = pd.DataFrame([list(df.loc[1])], columns=opp_columns)
    row3 = pd.DataFrame([list(df.loc[2])], columns=off_rank_columns)
    row4 = pd.DataFrame([list(df.loc[3])], columns=def_rank_columns)
    
    new_df = pd.concat([row1, row2, row3, row4], axis=1).reindex(row1.index)
    return new_df

def make_team_stats_one_row(df, draft_year, pick_number, team_name, position_drafted) -> 'DataFrame':
    df.drop(columns=['Team Player', 'Opp. Player', 'Off. Rank Player', 'Def. Rank Player'], inplace=True)
    df.insert(0, 'Pick Number', [pick_number], True)
    df.insert(0, 'Draft Year', [draft_year], True)
    df.insert(0, 'Team', [team_name], True)
    df.insert(0, 'Position Drafted', [position_drafted], True)
    return df

def get_raw_past_data() -> 'DataFrame':
    first_rounders = get_past_first_rounders()
    frames = []
    for i in first_rounders.index:
        row = list(first_rounders.loc[i])

        draft_year = row[0]
        pick_number = row[1]
        team_name = row[3]
        position_drafted = row[4]

        stats_url = get_team_stats_by_year_url(team_name, int(draft_year)-1)
        team_stats_df = get_team_stats(stats_url)
        if team_stats_df.empty:
            print('Not Found', stats_url)
            continue
        else:
            pass
        one_row = convert_team_stats_to_one_row(team_stats_df)
        final_row = make_team_stats_one_row(one_row, draft_year, pick_number, team_name, position_drafted)
        frames.append(final_row)
    final_df = pd.concat(frames)
    return final_df

# %%
raw = get_raw_past_data()
raw.to_csv('Raw Data For Last ' + str(YEARS) + ' Drafts.csv', encoding = 'utf-8-sig', index=False)
# Out:
# Scraping https://www.pro-football-reference.com/teams/cin/2019.htm
# Scraping https://www.pro-football-reference.com/teams/was/2019.htm
# Scraping https://www.pro-football-reference.com/teams/det/2019.htm
# Scraping https://www.pro-football-reference.com/teams/nyg/2019.htm
# Scraping https://www.pro-football-reference.com/teams/mia/2019.htm
# Scraping https://www.pro-football-reference.com/teams/sdg/2019.htm
# Scraping https://www.pro-football-reference.com/teams/car/2019.htm
# Scraping https://www.pro-football-reference.com/teams/crd/2019.htm
# Scraping https://www.pro-football-reference.com/teams/jax/2019.htm
# Scraping https://www.pro-football-reference.com/teams/cle/2019.htm
# Scraping https://www.pro-football-reference.com/teams/nyj/2019.htm
# Scraping https://www.pro-football-reference.com/teams/rai/2019.htm
# Scraping https://www.pro-football-reference.com/teams/tam/2019.htm
# Scraping https://www.pro-football-reference.com/teams/sfo/2019.htm
# Scraping https://www.pro-football-reference.com/teams/den/2019.htm
# Scraping https://www.pro-football-reference.com/teams/atl/2019.htm
# Scraping https://www.pro-football-reference.com/teams/dal/2019.htm
# Scraping https://www.pro-football-reference.com/teams/mia/2019.htm
# Scraping https://www.pro-football-reference.com/teams/rai/2019.htm
# Scraping https://www.pro-football-reference.com/teams/jax/2019.htm
# Scraping https://www.pro-football-reference.com/teams/phi/2019.htm
# Scraping https://www.pro-football-reference.com/teams/min/2019.htm
# Scraping https://www.pro-football-reference.com/teams/sdg/2019.htm
# Scraping https://www.pro-football-reference.com/teams/nor/2019.htm
# Scraping https://www.pro-football-reference.com/teams/sfo/2019.htm
# Scraping https://www.pro-football-reference.com/teams/gnb/2019.htm
# Scraping https://www.pro-football-reference.com/teams/sea/2019.htm
# Scraping https://www.pro-football-reference.com/teams/rav/2019.htm
# Scraping https://www.pro-football-reference.com/teams/oti/2019.htm
# Scraping https://www.pro-football-reference.com/teams/mia/2019.htm
# Scraping https://www.pro-football-reference.com/teams/min/2019.htm
# Scraping https://www.pro-football-reference.com/teams/kan/2019.htm
# Scraping https://www.pro-football-reference.com/teams/crd/2018.htm
# Scraping https://www.pro-football-reference.com/teams/sfo/2018.htm
# Scraping https://www.pro-football-reference.com/teams/nyj/2018.htm
# Scraping https://www.pro-football-reference.com/teams/rai/2018.htm
# Scraping https://www.pro-football-reference.com/teams/tam/2018.htm
# Scraping https://www.pro-football-reference.com/teams/nyg/2018.htm
# Scraping https://www.pro-football-reference.com/teams/jax/2018.htm
# Scraping https://www.pro-football-reference.com/teams/det/2018.htm
# Scraping https://www.pro-football-reference.com/teams/buf/2018.htm
# Scraping https://www.pro-football-reference.com/teams/pit/2018.htm
# Scraping https://www.pro-football-reference.com/teams/cin/2018.htm
# Scraping https://www.pro-football-reference.com/teams/gnb/2018.htm
# Scraping https://www.pro-football-reference.com/teams/mia/2018.htm
# Scraping https://www.pro-football-reference.com/teams/atl/2018.htm
# Scraping https://www.pro-football-reference.com/teams/was/2018.htm
# Scraping https://www.pro-football-reference.com/teams/car/2018.htm
# Scraping https://www.pro-football-reference.com/teams/nyg/2018.htm
# Scraping https://www.pro-football-reference.com/teams/min/2018.htm
# Scraping https://www.pro-football-reference.com/teams/oti/2018.htm
# Scraping https://www.pro-football-reference.com/teams/den/2018.htm
# Scraping https://www.pro-football-reference.com/teams/gnb/2018.htm
# Scraping https://www.pro-football-reference.com/teams/phi/2018.htm
# Scraping https://www.pro-football-reference.com/teams/htx/2018.htm
# Scraping https://www.pro-football-reference.com/teams/rai/2018.htm
# Scraping https://www.pro-football-reference.com/teams/rav/2018.htm
# Scraping https://www.pro-football-reference.com/teams/was/2018.htm
# Scraping https://www.pro-football-reference.com/teams/rai/2018.htm
# Scraping https://www.pro-football-reference.com/teams/sdg/2018.htm
# Scraping https://www.pro-football-reference.com/teams/sea/2018.htm
# Scraping https://www.pro-football-reference.com/teams/nyg/2018.htm
# Scraping https://www.pro-football-reference.com/teams/atl/2018.htm
# Scraping https://www.pro-football-reference.com/teams/nwe/2018.htm
# Scraping https://www.pro-football-reference.com/teams/cle/2017.htm
# Scraping https://www.pro-football-reference.com/teams/nyg/2017.htm
# Scraping https://www.pro-football-reference.com/teams/nyj/2017.htm
# Scraping https://www.pro-football-reference.com/teams/cle/2017.htm
# Scraping https://www.pro-football-reference.com/teams/den/2017.htm
# Scraping https://www.pro-football-reference.com/teams/clt/2017.htm
# Scraping https://www.pro-football-reference.com/teams/buf/2017.htm
# Scraping https://www.pro-football-reference.com/teams/chi/2017.htm
# Scraping https://www.pro-football-reference.com/teams/sfo/2017.htm
# Scraping https://www.pro-football-reference.com/teams/crd/2017.htm
# Scraping https://www.pro-football-reference.com/teams/mia/2017.htm
# Scraping https://www.pro-football-reference.com/teams/tam/2017.htm
# Scraping https://www.pro-football-reference.com/teams/was/2017.htm
# Scraping https://www.pro-football-reference.com/teams/nor/2017.htm
# Scraping https://www.pro-football-reference.com/teams/rai/2017.htm
# Scraping https://www.pro-football-reference.com/teams/buf/2017.htm
# Scraping https://www.pro-football-reference.com/teams/sdg/2017.htm
# Scraping https://www.pro-football-reference.com/teams/gnb/2017.htm
# Scraping https://www.pro-football-reference.com/teams/dal/2017.htm
# Scraping https://www.pro-football-reference.com/teams/det/2017.htm
# Scraping https://www.pro-football-reference.com/teams/cin/2017.htm
# Scraping https://www.pro-football-reference.com/teams/oti/2017.htm
# Scraping https://www.pro-football-reference.com/teams/nwe/2017.htm
# Scraping https://www.pro-football-reference.com/teams/car/2017.htm
# Scraping https://www.pro-football-reference.com/teams/rav/2017.htm
# Scraping https://www.pro-football-reference.com/teams/atl/2017.htm
# Scraping https://www.pro-football-reference.com/teams/sea/2017.htm
# Scraping https://www.pro-football-reference.com/teams/pit/2017.htm
# Scraping https://www.pro-football-reference.com/teams/jax/2017.htm
# Scraping https://www.pro-football-reference.com/teams/min/2017.htm
# Scraping https://www.pro-football-reference.com/teams/nwe/2017.htm
# Scraping https://www.pro-football-reference.com/teams/rav/2017.htm
# Scraping https://www.pro-football-reference.com/teams/cle/2016.htm
# Scraping https://www.pro-football-reference.com/teams/chi/2016.htm
# Scraping https://www.pro-football-reference.com/teams/sfo/2016.htm
# Scraping https://www.pro-football-reference.com/teams/jax/2016.htm
# Scraping https://www.pro-football-reference.com/teams/oti/2016.htm
# Scraping https://www.pro-football-reference.com/teams/nyj/2016.htm
# Scraping https://www.pro-football-reference.com/teams/sdg/2016.htm
# Scraping https://www.pro-football-reference.com/teams/car/2016.htm
# Scraping https://www.pro-football-reference.com/teams/cin/2016.htm
# Scraping https://www.pro-football-reference.com/teams/kan/2016.htm
# Scraping https://www.pro-football-reference.com/teams/nor/2016.htm
# Scraping https://www.pro-football-reference.com/teams/htx/2016.htm
# Scraping https://www.pro-football-reference.com/teams/crd/2016.htm
# Scraping https://www.pro-football-reference.com/teams/phi/2016.htm
# Scraping https://www.pro-football-reference.com/teams/clt/2016.htm
# Scraping https://www.pro-football-reference.com/teams/rav/2016.htm
# Scraping https://www.pro-football-reference.com/teams/was/2016.htm
# Scraping https://www.pro-football-reference.com/teams/oti/2016.htm
# Scraping https://www.pro-football-reference.com/teams/tam/2016.htm
# Scraping https://www.pro-football-reference.com/teams/den/2016.htm
# Scraping https://www.pro-football-reference.com/teams/det/2016.htm
# Scraping https://www.pro-football-reference.com/teams/mia/2016.htm
# Scraping https://www.pro-football-reference.com/teams/nyg/2016.htm
# Scraping https://www.pro-football-reference.com/teams/rai/2016.htm
# Scraping https://www.pro-football-reference.com/teams/cle/2016.htm
# Scraping https://www.pro-football-reference.com/teams/atl/2016.htm
# Scraping https://www.pro-football-reference.com/teams/buf/2016.htm
# Scraping https://www.pro-football-reference.com/teams/dal/2016.htm
# Scraping https://www.pro-football-reference.com/teams/cle/2016.htm
# Scraping https://www.pro-football-reference.com/teams/pit/2016.htm
# Scraping https://www.pro-football-reference.com/teams/sfo/2016.htm
# Scraping https://www.pro-football-reference.com/teams/nor/2016.htm
# Scraping https://www.pro-football-reference.com/teams/ram/2015.htm
# Scraping https://www.pro-football-reference.com/teams/phi/2015.htm
# Scraping https://www.pro-football-reference.com/teams/sdg/2015.htm
# Scraping https://www.pro-football-reference.com/teams/dal/2015.htm
# Scraping https://www.pro-football-reference.com/teams/jax/2015.htm
# Scraping https://www.pro-football-reference.com/teams/rav/2015.htm
# Scraping https://www.pro-football-reference.com/teams/sfo/2015.htm
# Scraping https://www.pro-football-reference.com/teams/oti/2015.htm
# Scraping https://www.pro-football-reference.com/teams/chi/2015.htm
# Scraping https://www.pro-football-reference.com/teams/nyg/2015.htm
# Scraping https://www.pro-football-reference.com/teams/tam/2015.htm
# Scraping https://www.pro-football-reference.com/teams/nor/2015.htm
# Scraping https://www.pro-football-reference.com/teams/mia/2015.htm
# Scraping https://www.pro-football-reference.com/teams/rai/2015.htm
# Scraping https://www.pro-football-reference.com/teams/cle/2015.htm
# Scraping https://www.pro-football-reference.com/teams/det/2015.htm
# Scraping https://www.pro-football-reference.com/teams/atl/2015.htm
# Scraping https://www.pro-football-reference.com/teams/clt/2015.htm
# Scraping https://www.pro-football-reference.com/teams/buf/2015.htm
# Scraping https://www.pro-football-reference.com/teams/nyj/2015.htm
# Scraping https://www.pro-football-reference.com/teams/htx/2015.htm
# Scraping https://www.pro-football-reference.com/teams/was/2015.htm
# Scraping https://www.pro-football-reference.com/teams/min/2015.htm
# Scraping https://www.pro-football-reference.com/teams/cin/2015.htm
# Scraping https://www.pro-football-reference.com/teams/pit/2015.htm
# Scraping https://www.pro-football-reference.com/teams/den/2015.htm
# Scraping https://www.pro-football-reference.com/teams/gnb/2015.htm
# Scraping https://www.pro-football-reference.com/teams/sfo/2015.htm
# Scraping https://www.pro-football-reference.com/teams/crd/2015.htm
# Scraping https://www.pro-football-reference.com/teams/car/2015.htm
# Scraping https://www.pro-football-reference.com/teams/sea/2015.htm
# Scraping https://www.pro-football-reference.com/teams/tam/2014.htm
# Scraping https://www.pro-football-reference.com/teams/oti/2014.htm
# Scraping https://www.pro-football-reference.com/teams/jax/2014.htm
# Scraping https://www.pro-football-reference.com/teams/rai/2014.htm
# Scraping https://www.pro-football-reference.com/teams/was/2014.htm
# Scraping https://www.pro-football-reference.com/teams/nyj/2014.htm
# Scraping https://www.pro-football-reference.com/teams/chi/2014.htm
# Scraping https://www.pro-football-reference.com/teams/atl/2014.htm
# Scraping https://www.pro-football-reference.com/teams/nyg/2014.htm
# Scraping https://www.pro-football-reference.com/teams/ram/2014.htm
# Scraping https://www.pro-football-reference.com/teams/min/2014.htm
# Scraping https://www.pro-football-reference.com/teams/cle/2014.htm
# Scraping https://www.pro-football-reference.com/teams/nor/2014.htm
# Scraping https://www.pro-football-reference.com/teams/mia/2014.htm
# Scraping https://www.pro-football-reference.com/teams/sdg/2014.htm
# Scraping https://www.pro-football-reference.com/teams/htx/2014.htm
# Scraping https://www.pro-football-reference.com/teams/sfo/2014.htm
# Scraping https://www.pro-football-reference.com/teams/kan/2014.htm
# Scraping https://www.pro-football-reference.com/teams/cle/2014.htm
# Scraping https://www.pro-football-reference.com/teams/phi/2014.htm
# Scraping https://www.pro-football-reference.com/teams/cin/2014.htm
# Scraping https://www.pro-football-reference.com/teams/pit/2014.htm
# Scraping https://www.pro-football-reference.com/teams/den/2014.htm
# Scraping https://www.pro-football-reference.com/teams/crd/2014.htm
# Scraping https://www.pro-football-reference.com/teams/car/2014.htm
# Scraping https://www.pro-football-reference.com/teams/rav/2014.htm
# Scraping https://www.pro-football-reference.com/teams/dal/2014.htm
# Scraping https://www.pro-football-reference.com/teams/det/2014.htm
# Scraping https://www.pro-football-reference.com/teams/clt/2014.htm
# Scraping https://www.pro-football-reference.com/teams/gnb/2014.htm
# Scraping https://www.pro-football-reference.com/teams/nor/2014.htm
# Scraping https://www.pro-football-reference.com/teams/nwe/2014.htm
# Scraping https://www.pro-football-reference.com/teams/htx/2013.htm
# Scraping https://www.pro-football-reference.com/teams/ram/2013.htm
# Scraping https://www.pro-football-reference.com/teams/jax/2013.htm
# Scraping https://www.pro-football-reference.com/teams/buf/2013.htm
# Scraping https://www.pro-football-reference.com/teams/rai/2013.htm
# Scraping https://www.pro-football-reference.com/teams/atl/2013.htm
# Scraping https://www.pro-football-reference.com/teams/tam/2013.htm
# Scraping https://www.pro-football-reference.com/teams/cle/2013.htm
# Scraping https://www.pro-football-reference.com/teams/min/2013.htm
# Scraping https://www.pro-football-reference.com/teams/det/2013.htm
# Scraping https://www.pro-football-reference.com/teams/oti/2013.htm
# Scraping https://www.pro-football-reference.com/teams/nyg/2013.htm
# Scraping https://www.pro-football-reference.com/teams/ram/2013.htm
# Scraping https://www.pro-football-reference.com/teams/chi/2013.htm
# Scraping https://www.pro-football-reference.com/teams/pit/2013.htm
# Scraping https://www.pro-football-reference.com/teams/dal/2013.htm
# Scraping https://www.pro-football-reference.com/teams/rav/2013.htm
# Scraping https://www.pro-football-reference.com/teams/nyj/2013.htm
# Scraping https://www.pro-football-reference.com/teams/mia/2013.htm
# Scraping https://www.pro-football-reference.com/teams/nor/2013.htm
# Scraping https://www.pro-football-reference.com/teams/gnb/2013.htm
# Scraping https://www.pro-football-reference.com/teams/cle/2013.htm
# Scraping https://www.pro-football-reference.com/teams/kan/2013.htm
# Scraping https://www.pro-football-reference.com/teams/cin/2013.htm
# Scraping https://www.pro-football-reference.com/teams/sdg/2013.htm
# Scraping https://www.pro-football-reference.com/teams/phi/2013.htm
# Scraping https://www.pro-football-reference.com/teams/crd/2013.htm
# Scraping https://www.pro-football-reference.com/teams/car/2013.htm
# Scraping https://www.pro-football-reference.com/teams/nwe/2013.htm
# Scraping https://www.pro-football-reference.com/teams/sfo/2013.htm
# Scraping https://www.pro-football-reference.com/teams/den/2013.htm
# Scraping https://www.pro-football-reference.com/teams/min/2013.htm
# Scraping https://www.pro-football-reference.com/teams/kan/2012.htm
# Scraping https://www.pro-football-reference.com/teams/jax/2012.htm
# Scraping https://www.pro-football-reference.com/teams/mia/2012.htm
# Scraping https://www.pro-football-reference.com/teams/phi/2012.htm
# Scraping https://www.pro-football-reference.com/teams/det/2012.htm
# Scraping https://www.pro-football-reference.com/teams/cle/2012.htm
# Scraping https://www.pro-football-reference.com/teams/crd/2012.htm
# Scraping https://www.pro-football-reference.com/teams/ram/2012.htm
# Scraping https://www.pro-football-reference.com/teams/nyj/2012.htm
# Scraping https://www.pro-football-reference.com/teams/oti/2012.htm
# Scraping https://www.pro-football-reference.com/teams/sdg/2012.htm
# Scraping https://www.pro-football-reference.com/teams/rai/2012.htm
# Scraping https://www.pro-football-reference.com/teams/nyj/2012.htm
# Scraping https://www.pro-football-reference.com/teams/car/2012.htm
# Scraping https://www.pro-football-reference.com/teams/nor/2012.htm
# Scraping https://www.pro-football-reference.com/teams/buf/2012.htm
# Scraping https://www.pro-football-reference.com/teams/pit/2012.htm
# Scraping https://www.pro-football-reference.com/teams/sfo/2012.htm
# Scraping https://www.pro-football-reference.com/teams/nyg/2012.htm
# Scraping https://www.pro-football-reference.com/teams/chi/2012.htm
# Scraping https://www.pro-football-reference.com/teams/cin/2012.htm
# Scraping https://www.pro-football-reference.com/teams/atl/2012.htm
# Scraping https://www.pro-football-reference.com/teams/min/2012.htm
# Scraping https://www.pro-football-reference.com/teams/clt/2012.htm
# Scraping https://www.pro-football-reference.com/teams/min/2012.htm
# Scraping https://www.pro-football-reference.com/teams/gnb/2012.htm
# Scraping https://www.pro-football-reference.com/teams/htx/2012.htm
# Scraping https://www.pro-football-reference.com/teams/den/2012.htm
# Scraping https://www.pro-football-reference.com/teams/min/2012.htm
# Scraping https://www.pro-football-reference.com/teams/ram/2012.htm
# Scraping https://www.pro-football-reference.com/teams/dal/2012.htm
# Scraping https://www.pro-football-reference.com/teams/rav/2012.htm
# Scraping https://www.pro-football-reference.com/teams/clt/2011.htm
# Scraping https://www.pro-football-reference.com/teams/was/2011.htm
# Scraping https://www.pro-football-reference.com/teams/cle/2011.htm
# Scraping https://www.pro-football-reference.com/teams/min/2011.htm
# Scraping https://www.pro-football-reference.com/teams/jax/2011.htm
# Scraping https://www.pro-football-reference.com/teams/dal/2011.htm
# Scraping https://www.pro-football-reference.com/teams/tam/2011.htm
# Scraping https://www.pro-football-reference.com/teams/mia/2011.htm
# Scraping https://www.pro-football-reference.com/teams/car/2011.htm
# Scraping https://www.pro-football-reference.com/teams/buf/2011.htm
# Scraping https://www.pro-football-reference.com/teams/kan/2011.htm
# Scraping https://www.pro-football-reference.com/teams/phi/2011.htm
# Scraping https://www.pro-football-reference.com/teams/crd/2011.htm
# Scraping https://www.pro-football-reference.com/teams/ram/2011.htm
# Scraping https://www.pro-football-reference.com/teams/sea/2011.htm
# Scraping https://www.pro-football-reference.com/teams/nyj/2011.htm
# Scraping https://www.pro-football-reference.com/teams/cin/2011.htm
# Scraping https://www.pro-football-reference.com/teams/sdg/2011.htm
# Scraping https://www.pro-football-reference.com/teams/chi/2011.htm
# Scraping https://www.pro-football-reference.com/teams/oti/2011.htm
# Scraping https://www.pro-football-reference.com/teams/nwe/2011.htm
# Scraping https://www.pro-football-reference.com/teams/cle/2011.htm
# Scraping https://www.pro-football-reference.com/teams/det/2011.htm
# Scraping https://www.pro-football-reference.com/teams/pit/2011.htm
# Scraping https://www.pro-football-reference.com/teams/nwe/2011.htm
# Scraping https://www.pro-football-reference.com/teams/htx/2011.htm
# Scraping https://www.pro-football-reference.com/teams/cin/2011.htm
# Scraping https://www.pro-football-reference.com/teams/gnb/2011.htm
# Scraping https://www.pro-football-reference.com/teams/min/2011.htm
# Scraping https://www.pro-football-reference.com/teams/sfo/2011.htm
# Scraping https://www.pro-football-reference.com/teams/tam/2011.htm
# Scraping https://www.pro-football-reference.com/teams/nyg/2011.htm
# Scraping https://www.pro-football-reference.com/teams/car/2010.htm
# Scraping https://www.pro-football-reference.com/teams/den/2010.htm
# Scraping https://www.pro-football-reference.com/teams/buf/2010.htm
# Scraping https://www.pro-football-reference.com/teams/cin/2010.htm
# Scraping https://www.pro-football-reference.com/teams/crd/2010.htm
# Scraping https://www.pro-football-reference.com/teams/atl/2010.htm
# Scraping https://www.pro-football-reference.com/teams/sfo/2010.htm
# Scraping https://www.pro-football-reference.com/teams/oti/2010.htm
# Scraping https://www.pro-football-reference.com/teams/dal/2010.htm
# Scraping https://www.pro-football-reference.com/teams/jax/2010.htm
# Scraping https://www.pro-football-reference.com/teams/htx/2010.htm
# Scraping https://www.pro-football-reference.com/teams/min/2010.htm
# Scraping https://www.pro-football-reference.com/teams/det/2010.htm
# Scraping https://www.pro-football-reference.com/teams/ram/2010.htm
# Scraping https://www.pro-football-reference.com/teams/mia/2010.htm
# Scraping https://www.pro-football-reference.com/teams/was/2010.htm
# Scraping https://www.pro-football-reference.com/teams/nwe/2010.htm
# Scraping https://www.pro-football-reference.com/teams/sdg/2010.htm
# Scraping https://www.pro-football-reference.com/teams/nyg/2010.htm
# Scraping https://www.pro-football-reference.com/teams/tam/2010.htm
# Scraping https://www.pro-football-reference.com/teams/cle/2010.htm
# Scraping https://www.pro-football-reference.com/teams/clt/2010.htm
# Scraping https://www.pro-football-reference.com/teams/phi/2010.htm
# Scraping https://www.pro-football-reference.com/teams/nor/2010.htm
# Scraping https://www.pro-football-reference.com/teams/sea/2010.htm
# Scraping https://www.pro-football-reference.com/teams/kan/2010.htm
# Scraping https://www.pro-football-reference.com/teams/rav/2010.htm
# Scraping https://www.pro-football-reference.com/teams/nor/2010.htm
# Scraping https://www.pro-football-reference.com/teams/chi/2010.htm
# Scraping https://www.pro-football-reference.com/teams/nyj/2010.htm
# Scraping https://www.pro-football-reference.com/teams/pit/2010.htm
# Scraping https://www.pro-football-reference.com/teams/gnb/2010.htm
# Scraping https://www.pro-football-reference.com/teams/ram/2009.htm
# Scraping https://www.pro-football-reference.com/teams/det/2009.htm
# Scraping https://www.pro-football-reference.com/teams/tam/2009.htm
# Scraping https://www.pro-football-reference.com/teams/was/2009.htm
# Scraping https://www.pro-football-reference.com/teams/kan/2009.htm
# Scraping https://www.pro-football-reference.com/teams/sea/2009.htm
# Scraping https://www.pro-football-reference.com/teams/cle/2009.htm
# Scraping https://www.pro-football-reference.com/teams/rai/2009.htm
# Scraping https://www.pro-football-reference.com/teams/buf/2009.htm
# Scraping https://www.pro-football-reference.com/teams/jax/2009.htm
# Scraping https://www.pro-football-reference.com/teams/sfo/2009.htm
# Scraping https://www.pro-football-reference.com/teams/sdg/2009.htm
# Scraping https://www.pro-football-reference.com/teams/phi/2009.htm
# Scraping https://www.pro-football-reference.com/teams/sea/2009.htm
# Scraping https://www.pro-football-reference.com/teams/nyg/2009.htm
# Scraping https://www.pro-football-reference.com/teams/oti/2009.htm
# Scraping https://www.pro-football-reference.com/teams/sfo/2009.htm
# Scraping https://www.pro-football-reference.com/teams/pit/2009.htm
# Scraping https://www.pro-football-reference.com/teams/atl/2009.htm
# Scraping https://www.pro-football-reference.com/teams/htx/2009.htm
# Scraping https://www.pro-football-reference.com/teams/cin/2009.htm
# Scraping https://www.pro-football-reference.com/teams/den/2009.htm
# Scraping https://www.pro-football-reference.com/teams/gnb/2009.htm
# Scraping https://www.pro-football-reference.com/teams/dal/2009.htm
# Scraping https://www.pro-football-reference.com/teams/den/2009.htm
# Scraping https://www.pro-football-reference.com/teams/crd/2009.htm
# Scraping https://www.pro-football-reference.com/teams/nwe/2009.htm
# Scraping https://www.pro-football-reference.com/teams/mia/2009.htm
# Scraping https://www.pro-football-reference.com/teams/nyj/2009.htm
# Scraping https://www.pro-football-reference.com/teams/det/2009.htm
# Scraping https://www.pro-football-reference.com/teams/clt/2009.htm
# Scraping https://www.pro-football-reference.com/teams/nor/2009.htm
# Scraping https://www.pro-football-reference.com/teams/det/2008.htm
# Scraping https://www.pro-football-reference.com/teams/ram/2008.htm
# Scraping https://www.pro-football-reference.com/teams/kan/2008.htm
# Scraping https://www.pro-football-reference.com/teams/sea/2008.htm
# Scraping https://www.pro-football-reference.com/teams/nyj/2008.htm
# Scraping https://www.pro-football-reference.com/teams/cin/2008.htm
# Scraping https://www.pro-football-reference.com/teams/rai/2008.htm
# Scraping https://www.pro-football-reference.com/teams/jax/2008.htm
# Scraping https://www.pro-football-reference.com/teams/gnb/2008.htm
# Scraping https://www.pro-football-reference.com/teams/sfo/2008.htm
# Scraping https://www.pro-football-reference.com/teams/buf/2008.htm
# Scraping https://www.pro-football-reference.com/teams/den/2008.htm
# Scraping https://www.pro-football-reference.com/teams/was/2008.htm
# Scraping https://www.pro-football-reference.com/teams/nor/2008.htm
# Scraping https://www.pro-football-reference.com/teams/htx/2008.htm
# Scraping https://www.pro-football-reference.com/teams/sdg/2008.htm
# Scraping https://www.pro-football-reference.com/teams/tam/2008.htm
# Scraping https://www.pro-football-reference.com/teams/den/2008.htm
# Scraping https://www.pro-football-reference.com/teams/phi/2008.htm
# Scraping https://www.pro-football-reference.com/teams/det/2008.htm
# Scraping https://www.pro-football-reference.com/teams/cle/2008.htm
# Scraping https://www.pro-football-reference.com/teams/min/2008.htm
# Scraping https://www.pro-football-reference.com/teams/rav/2008.htm
# Scraping https://www.pro-football-reference.com/teams/atl/2008.htm
# Scraping https://www.pro-football-reference.com/teams/mia/2008.htm
# Scraping https://www.pro-football-reference.com/teams/gnb/2008.htm
# Scraping https://www.pro-football-reference.com/teams/clt/2008.htm
# Scraping https://www.pro-football-reference.com/teams/buf/2008.htm
# Scraping https://www.pro-football-reference.com/teams/nyg/2008.htm
# Scraping https://www.pro-football-reference.com/teams/oti/2008.htm
# Scraping https://www.pro-football-reference.com/teams/crd/2008.htm
# Scraping https://www.pro-football-reference.com/teams/pit/2008.htm
# Scraping https://www.pro-football-reference.com/teams/mia/2007.htm
# Scraping https://www.pro-football-reference.com/teams/ram/2007.htm
# Scraping https://www.pro-football-reference.com/teams/atl/2007.htm
# Scraping https://www.pro-football-reference.com/teams/rai/2007.htm
# Scraping https://www.pro-football-reference.com/teams/kan/2007.htm
# Scraping https://www.pro-football-reference.com/teams/nyj/2007.htm
# Scraping https://www.pro-football-reference.com/teams/nor/2007.htm
# Scraping https://www.pro-football-reference.com/teams/jax/2007.htm
# Scraping https://www.pro-football-reference.com/teams/cin/2007.htm
# Scraping https://www.pro-football-reference.com/teams/nwe/2007.htm
# Scraping https://www.pro-football-reference.com/teams/buf/2007.htm
# Scraping https://www.pro-football-reference.com/teams/den/2007.htm
# Scraping https://www.pro-football-reference.com/teams/car/2007.htm
# Scraping https://www.pro-football-reference.com/teams/chi/2007.htm
# Scraping https://www.pro-football-reference.com/teams/kan/2007.htm
# Scraping https://www.pro-football-reference.com/teams/crd/2007.htm
# Scraping https://www.pro-football-reference.com/teams/det/2007.htm
# Scraping https://www.pro-football-reference.com/teams/rav/2007.htm
# Scraping https://www.pro-football-reference.com/teams/car/2007.htm
# Scraping https://www.pro-football-reference.com/teams/tam/2007.htm
# Scraping https://www.pro-football-reference.com/teams/atl/2007.htm
# Scraping https://www.pro-football-reference.com/teams/dal/2007.htm
# Scraping https://www.pro-football-reference.com/teams/pit/2007.htm
# Scraping https://www.pro-football-reference.com/teams/oti/2007.htm
# Scraping https://www.pro-football-reference.com/teams/dal/2007.htm
# Scraping https://www.pro-football-reference.com/teams/htx/2007.htm
# Scraping https://www.pro-football-reference.com/teams/sdg/2007.htm
# Scraping https://www.pro-football-reference.com/teams/sea/2007.htm
# Scraping https://www.pro-football-reference.com/teams/sfo/2007.htm
# Scraping https://www.pro-football-reference.com/teams/nyj/2007.htm
# Scraping https://www.pro-football-reference.com/teams/nyg/2007.htm
# Scraping https://www.pro-football-reference.com/teams/rai/2006.htm
# Scraping https://www.pro-football-reference.com/teams/det/2006.htm
# Scraping https://www.pro-football-reference.com/teams/cle/2006.htm
# Scraping https://www.pro-football-reference.com/teams/tam/2006.htm
# Scraping https://www.pro-football-reference.com/teams/crd/2006.htm
# Scraping https://www.pro-football-reference.com/teams/was/2006.htm
# Scraping https://www.pro-football-reference.com/teams/min/2006.htm
# Scraping https://www.pro-football-reference.com/teams/atl/2006.htm
# Scraping https://www.pro-football-reference.com/teams/mia/2006.htm
# Scraping https://www.pro-football-reference.com/teams/htx/2006.htm
# Scraping https://www.pro-football-reference.com/teams/sfo/2006.htm
# Scraping https://www.pro-football-reference.com/teams/buf/2006.htm
# Scraping https://www.pro-football-reference.com/teams/ram/2006.htm
# Scraping https://www.pro-football-reference.com/teams/nyj/2006.htm
# Scraping https://www.pro-football-reference.com/teams/pit/2006.htm
# Scraping https://www.pro-football-reference.com/teams/gnb/2006.htm
# Scraping https://www.pro-football-reference.com/teams/den/2006.htm
# Scraping https://www.pro-football-reference.com/teams/cin/2006.htm
# Scraping https://www.pro-football-reference.com/teams/oti/2006.htm
# Scraping https://www.pro-football-reference.com/teams/nyg/2006.htm
# Scraping https://www.pro-football-reference.com/teams/jax/2006.htm
# Scraping https://www.pro-football-reference.com/teams/cle/2006.htm
# Scraping https://www.pro-football-reference.com/teams/kan/2006.htm
# Scraping https://www.pro-football-reference.com/teams/nwe/2006.htm
# Scraping https://www.pro-football-reference.com/teams/car/2006.htm
# Scraping https://www.pro-football-reference.com/teams/dal/2006.htm
# Scraping https://www.pro-football-reference.com/teams/nor/2006.htm
# Scraping https://www.pro-football-reference.com/teams/sfo/2006.htm
# Scraping https://www.pro-football-reference.com/teams/rav/2006.htm
# Scraping https://www.pro-football-reference.com/teams/sdg/2006.htm
# Scraping https://www.pro-football-reference.com/teams/chi/2006.htm
# Scraping https://www.pro-football-reference.com/teams/clt/2006.htm
# Scraping https://www.pro-football-reference.com/teams/htx/2005.htm
# Scraping https://www.pro-football-reference.com/teams/nor/2005.htm
# Scraping https://www.pro-football-reference.com/teams/oti/2005.htm
# Scraping https://www.pro-football-reference.com/teams/nyj/2005.htm
# Scraping https://www.pro-football-reference.com/teams/gnb/2005.htm
# Scraping https://www.pro-football-reference.com/teams/sfo/2005.htm
# Scraping https://www.pro-football-reference.com/teams/rai/2005.htm
# Scraping https://www.pro-football-reference.com/teams/buf/2005.htm
# Scraping https://www.pro-football-reference.com/teams/det/2005.htm
# Scraping https://www.pro-football-reference.com/teams/crd/2005.htm
# Scraping https://www.pro-football-reference.com/teams/den/2005.htm
# Scraping https://www.pro-football-reference.com/teams/rav/2005.htm
# Scraping https://www.pro-football-reference.com/teams/cle/2005.htm
# Scraping https://www.pro-football-reference.com/teams/phi/2005.htm
# Scraping https://www.pro-football-reference.com/teams/ram/2005.htm
# Scraping https://www.pro-football-reference.com/teams/mia/2005.htm
# Scraping https://www.pro-football-reference.com/teams/min/2005.htm
# Scraping https://www.pro-football-reference.com/teams/dal/2005.htm
# Scraping https://www.pro-football-reference.com/teams/sdg/2005.htm
# Scraping https://www.pro-football-reference.com/teams/kan/2005.htm
# Scraping https://www.pro-football-reference.com/teams/nwe/2005.htm
# Scraping https://www.pro-football-reference.com/teams/sfo/2005.htm
# Scraping https://www.pro-football-reference.com/teams/tam/2005.htm
# Scraping https://www.pro-football-reference.com/teams/cin/2005.htm
# Scraping https://www.pro-football-reference.com/teams/pit/2005.htm
# Scraping https://www.pro-football-reference.com/teams/buf/2005.htm
# Scraping https://www.pro-football-reference.com/teams/car/2005.htm
# Scraping https://www.pro-football-reference.com/teams/jax/2005.htm
# Scraping https://www.pro-football-reference.com/teams/nyj/2005.htm
# Scraping https://www.pro-football-reference.com/teams/clt/2005.htm
# Scraping https://www.pro-football-reference.com/teams/sea/2005.htm
# Scraping https://www.pro-football-reference.com/teams/nyg/2005.htm
# Scraping https://www.pro-football-reference.com/teams/sfo/2004.htm
# Scraping https://www.pro-football-reference.com/teams/mia/2004.htm
# Scraping https://www.pro-football-reference.com/teams/cle/2004.htm
# Scraping https://www.pro-football-reference.com/teams/chi/2004.htm
# Scraping https://www.pro-football-reference.com/teams/tam/2004.htm
# Scraping https://www.pro-football-reference.com/teams/oti/2004.htm
# Scraping https://www.pro-football-reference.com/teams/min/2004.htm
# Scraping https://www.pro-football-reference.com/teams/crd/2004.htm
# Scraping https://www.pro-football-reference.com/teams/was/2004.htm
# Scraping https://www.pro-football-reference.com/teams/det/2004.htm
# Scraping https://www.pro-football-reference.com/teams/dal/2004.htm
# Scraping https://www.pro-football-reference.com/teams/sdg/2004.htm
# Scraping https://www.pro-football-reference.com/teams/nor/2004.htm
# Scraping https://www.pro-football-reference.com/teams/car/2004.htm
# Scraping https://www.pro-football-reference.com/teams/kan/2004.htm
# Scraping https://www.pro-football-reference.com/teams/htx/2004.htm
# Scraping https://www.pro-football-reference.com/teams/cin/2004.htm
# Scraping https://www.pro-football-reference.com/teams/min/2004.htm
# Scraping https://www.pro-football-reference.com/teams/ram/2004.htm
# Scraping https://www.pro-football-reference.com/teams/dal/2004.htm
# Scraping https://www.pro-football-reference.com/teams/jax/2004.htm
# Scraping https://www.pro-football-reference.com/teams/rav/2004.htm
# Scraping https://www.pro-football-reference.com/teams/rai/2004.htm
# Scraping https://www.pro-football-reference.com/teams/gnb/2004.htm
# Scraping https://www.pro-football-reference.com/teams/was/2004.htm
# Scraping https://www.pro-football-reference.com/teams/sea/2004.htm
# Scraping https://www.pro-football-reference.com/teams/atl/2004.htm
# Scraping https://www.pro-football-reference.com/teams/sdg/2004.htm
# Scraping https://www.pro-football-reference.com/teams/clt/2004.htm
# Scraping https://www.pro-football-reference.com/teams/pit/2004.htm
# Scraping https://www.pro-football-reference.com/teams/phi/2004.htm
# Scraping https://www.pro-football-reference.com/teams/nwe/2004.htm
# Scraping https://www.pro-football-reference.com/teams/sdg/2003.htm
# Scraping https://www.pro-football-reference.com/teams/rai/2003.htm
# Scraping https://www.pro-football-reference.com/teams/crd/2003.htm
# Scraping https://www.pro-football-reference.com/teams/nyg/2003.htm
# Scraping https://www.pro-football-reference.com/teams/was/2003.htm
# Scraping https://www.pro-football-reference.com/teams/cle/2003.htm
# Scraping https://www.pro-football-reference.com/teams/det/2003.htm
# Scraping https://www.pro-football-reference.com/teams/atl/2003.htm
# Scraping https://www.pro-football-reference.com/teams/jax/2003.htm
# Scraping https://www.pro-football-reference.com/teams/htx/2003.htm
# Scraping https://www.pro-football-reference.com/teams/pit/2003.htm
# Scraping https://www.pro-football-reference.com/teams/nyj/2003.htm
# Scraping https://www.pro-football-reference.com/teams/buf/2003.htm
# Scraping https://www.pro-football-reference.com/teams/chi/2003.htm
# Scraping https://www.pro-football-reference.com/teams/tam/2003.htm
# Scraping https://www.pro-football-reference.com/teams/phi/2003.htm
# Scraping https://www.pro-football-reference.com/teams/den/2003.htm
# Scraping https://www.pro-football-reference.com/teams/nor/2003.htm
# Scraping https://www.pro-football-reference.com/teams/mia/2003.htm
# Scraping https://www.pro-football-reference.com/teams/min/2003.htm
# Scraping https://www.pro-football-reference.com/teams/nwe/2003.htm
# Scraping https://www.pro-football-reference.com/teams/buf/2003.htm
# Scraping https://www.pro-football-reference.com/teams/sea/2003.htm
# Scraping https://www.pro-football-reference.com/teams/ram/2003.htm
# Scraping https://www.pro-football-reference.com/teams/gnb/2003.htm
# Scraping https://www.pro-football-reference.com/teams/cin/2003.htm
# Scraping https://www.pro-football-reference.com/teams/htx/2003.htm
# Scraping https://www.pro-football-reference.com/teams/car/2003.htm
# Scraping https://www.pro-football-reference.com/teams/atl/2003.htm
# Scraping https://www.pro-football-reference.com/teams/det/2003.htm
# Scraping https://www.pro-football-reference.com/teams/sfo/2003.htm
# Scraping https://www.pro-football-reference.com/teams/nwe/2003.htm
# Scraping https://www.pro-football-reference.com/teams/cin/2002.htm
# Scraping https://www.pro-football-reference.com/teams/det/2002.htm
# Scraping https://www.pro-football-reference.com/teams/htx/2002.htm
# Scraping https://www.pro-football-reference.com/teams/nyj/2002.htm
# Scraping https://www.pro-football-reference.com/teams/dal/2002.htm
# Scraping https://www.pro-football-reference.com/teams/nor/2002.htm
# Scraping https://www.pro-football-reference.com/teams/jax/2002.htm
# Scraping https://www.pro-football-reference.com/teams/car/2002.htm
# Scraping https://www.pro-football-reference.com/teams/min/2002.htm
# Scraping https://www.pro-football-reference.com/teams/rav/2002.htm
# Scraping https://www.pro-football-reference.com/teams/sea/2002.htm
# Scraping https://www.pro-football-reference.com/teams/ram/2002.htm
# Scraping https://www.pro-football-reference.com/teams/nwe/2002.htm
# Scraping https://www.pro-football-reference.com/teams/chi/2002.htm
# Scraping https://www.pro-football-reference.com/teams/phi/2002.htm
# Scraping https://www.pro-football-reference.com/teams/pit/2002.htm
# Scraping https://www.pro-football-reference.com/teams/crd/2002.htm
# Scraping https://www.pro-football-reference.com/teams/crd/2002.htm
# Scraping https://www.pro-football-reference.com/teams/rav/2002.htm
# Scraping https://www.pro-football-reference.com/teams/den/2002.htm
# Scraping https://www.pro-football-reference.com/teams/cle/2002.htm
# Scraping https://www.pro-football-reference.com/teams/chi/2002.htm
# Scraping https://www.pro-football-reference.com/teams/buf/2002.htm
# Scraping https://www.pro-football-reference.com/teams/clt/2002.htm
# Scraping https://www.pro-football-reference.com/teams/nyg/2002.htm
# Scraping https://www.pro-football-reference.com/teams/sfo/2002.htm
# Scraping https://www.pro-football-reference.com/teams/kan/2002.htm
# Scraping https://www.pro-football-reference.com/teams/oti/2002.htm
# Scraping https://www.pro-football-reference.com/teams/gnb/2002.htm
# Scraping https://www.pro-football-reference.com/teams/sdg/2002.htm
# Scraping https://www.pro-football-reference.com/teams/rai/2002.htm
# Scraping https://www.pro-football-reference.com/teams/rai/2002.htm
# Not Found https://www.pro-football-reference.com/teams/htx/2001.htm
# Scraping https://www.pro-football-reference.com/teams/car/2001.htm
# Scraping https://www.pro-football-reference.com/teams/det/2001.htm
# Scraping https://www.pro-football-reference.com/teams/buf/2001.htm
# Scraping https://www.pro-football-reference.com/teams/sdg/2001.htm
# Scraping https://www.pro-football-reference.com/teams/kan/2001.htm
# Scraping https://www.pro-football-reference.com/teams/min/2001.htm
# Scraping https://www.pro-football-reference.com/teams/dal/2001.htm
# Scraping https://www.pro-football-reference.com/teams/jax/2001.htm
# Scraping https://www.pro-football-reference.com/teams/cin/2001.htm
# Scraping https://www.pro-football-reference.com/teams/clt/2001.htm
# Scraping https://www.pro-football-reference.com/teams/crd/2001.htm
# Scraping https://www.pro-football-reference.com/teams/nor/2001.htm
# Scraping https://www.pro-football-reference.com/teams/nyg/2001.htm
# Scraping https://www.pro-football-reference.com/teams/oti/2001.htm
# Scraping https://www.pro-football-reference.com/teams/cle/2001.htm
# Scraping https://www.pro-football-reference.com/teams/rai/2001.htm
# Scraping https://www.pro-football-reference.com/teams/atl/2001.htm
# Scraping https://www.pro-football-reference.com/teams/den/2001.htm
# Scraping https://www.pro-football-reference.com/teams/gnb/2001.htm
# Scraping https://www.pro-football-reference.com/teams/nwe/2001.htm
# Scraping https://www.pro-football-reference.com/teams/nyj/2001.htm
# Scraping https://www.pro-football-reference.com/teams/rai/2001.htm
# Scraping https://www.pro-football-reference.com/teams/rav/2001.htm
# Scraping https://www.pro-football-reference.com/teams/nor/2001.htm
# Scraping https://www.pro-football-reference.com/teams/phi/2001.htm
# Scraping https://www.pro-football-reference.com/teams/sfo/2001.htm
# Scraping https://www.pro-football-reference.com/teams/sea/2001.htm
# Scraping https://www.pro-football-reference.com/teams/chi/2001.htm
# Scraping https://www.pro-football-reference.com/teams/pit/2001.htm
# Scraping https://www.pro-football-reference.com/teams/ram/2001.htm
# Scraping https://www.pro-football-reference.com/teams/was/2001.htm
# Scraping https://www.pro-football-reference.com/teams/atl/2000.htm
# Scraping https://www.pro-football-reference.com/teams/crd/2000.htm
# Scraping https://www.pro-football-reference.com/teams/cle/2000.htm
# Scraping https://www.pro-football-reference.com/teams/cin/2000.htm
# Scraping https://www.pro-football-reference.com/teams/sdg/2000.htm
# Scraping https://www.pro-football-reference.com/teams/nwe/2000.htm
# Scraping https://www.pro-football-reference.com/teams/sfo/2000.htm
# Scraping https://www.pro-football-reference.com/teams/chi/2000.htm
# Scraping https://www.pro-football-reference.com/teams/sea/2000.htm
# Scraping https://www.pro-football-reference.com/teams/gnb/2000.htm
# Scraping https://www.pro-football-reference.com/teams/car/2000.htm
# Scraping https://www.pro-football-reference.com/teams/ram/2000.htm
# Scraping https://www.pro-football-reference.com/teams/jax/2000.htm
# Scraping https://www.pro-football-reference.com/teams/tam/2000.htm
# Scraping https://www.pro-football-reference.com/teams/was/2000.htm
# Scraping https://www.pro-football-reference.com/teams/nyj/2000.htm
# Scraping https://www.pro-football-reference.com/teams/sea/2000.htm
# Scraping https://www.pro-football-reference.com/teams/det/2000.htm
# Scraping https://www.pro-football-reference.com/teams/pit/2000.htm
# Scraping https://www.pro-football-reference.com/teams/ram/2000.htm
# Scraping https://www.pro-football-reference.com/teams/buf/2000.htm
# Scraping https://www.pro-football-reference.com/teams/nyg/2000.htm
# Scraping https://www.pro-football-reference.com/teams/nor/2000.htm
# Scraping https://www.pro-football-reference.com/teams/den/2000.htm
# Scraping https://www.pro-football-reference.com/teams/phi/2000.htm
# Scraping https://www.pro-football-reference.com/teams/mia/2000.htm
# Scraping https://www.pro-football-reference.com/teams/min/2000.htm
# Scraping https://www.pro-football-reference.com/teams/rai/2000.htm
# Scraping https://www.pro-football-reference.com/teams/ram/2000.htm
# Scraping https://www.pro-football-reference.com/teams/clt/2000.htm
# Scraping https://www.pro-football-reference.com/teams/rav/2000.htm

# %%
# Notice that certain values are not Null=NaN, but empty
raw
# Out:
#    Position Drafted      Team Draft Year Pick Number  Team PF  Team Yds  \
# 0                QB   Bengals       2020           1    279.0    5169.0
# 0                DE  Redskins       2020           2    266.0    4395.0
# 0                DB     Lions       2020           3    341.0    5549.0
# 0                 T    Giants       2020           4    341.0    5416.0
# 0                QB  Dolphins       2020           5    306.0    4960.0
# ..              ...       ...        ...         ...      ...       ...
# 0                RB   Vikings       2001          27    397.0    5961.0
# 0                DB   Raiders       2001          28    479.0    5776.0
# 0                DE      Rams       2001          29    540.0    7075.0
# 0                WR     Colts       2001          30    429.0    6141.0
# 0                TE    Ravens       2001          31    333.0    5014.0
#
#     Team Ply  Team Y/P  Team TO  Team FL  ...  Def. Rank Yds  Def. Rank 1stPy  \
# 0     1049.0       4.9     30.0     14.0  ...
# 0      885.0       5.0     21.0      8.0  ...
# 0     1021.0       5.4     23.0      8.0  ...
# 0     1012.0       5.4     33.0     16.0  ...
# 0     1022.0       4.9     26.0      8.0  ...
# ..       ...       ...      ...      ...  ...            ...              ...
# 0      958.0       6.2     28.0     10.0  ...
# 0     1023.0       5.6     20.0      9.0  ...
# 0     1014.0       7.0     35.0     12.0  ...
# 0     1026.0       6.0     29.0     14.0  ...
# 0     1058.0       4.7     26.0      7.0  ...
#
#     Def. Rank #Dr  Def. Rank Sc%  Def. Rank TO%  Def. Rank Start  \
# 0                            9.0           27.0             12.0
# 0                            4.0           15.0             31.0
# 0                            7.0           25.0              3.0
# 0                            8.0           29.0             25.0
# 0                            1.0           28.0             27.0
# ..            ...            ...            ...              ...
# 0                            6.0           31.0              7.0
# 0                           24.0            7.0              1.0
# 0                            2.0           22.0             25.0
# 0                           12.0           23.0              3.0
# 0                           31.0            1.0              2.0
#
#     Def. Rank Time  Def. Rank Plays  Def. Rank Yds  Def. Rank Pts
# 0             18.0             15.0           28.0           22.0
# 0             31.0             29.0           29.0           30.0
# 0             21.0             28.0           30.0           24.0
# 0             19.0             17.0           20.0           25.0
# 0             20.0             20.0           26.0           32.0
# ..             ...              ...            ...            ...
# 0             30.0             30.0           30.0           27.0
# 0              5.0             15.0           18.0           11.0
# 0             15.0             14.0           24.0           30.0
# 0             25.0             28.0           25.0           19.0
# 0              1.0              1.0            2.0            1.0
#
# [636 rows x 124 columns]

# %%
# Recreate raw data from file so that empty values are not perceived as Null=NaN
raw = pd.read_csv('Raw Data For Last ' + str(YEARS) + ' Drafts.csv', encoding = 'utf-8')
raw
# Out:
#     Position Drafted      Team  Draft Year  Pick Number  Team PF  Team Yds  \
# 0                 QB   Bengals        2020            1    279.0    5169.0
# 1                 DE  Redskins        2020            2    266.0    4395.0
# 2                 DB     Lions        2020            3    341.0    5549.0
# 3                  T    Giants        2020            4    341.0    5416.0
# 4                 QB  Dolphins        2020            5    306.0    4960.0
# ..               ...       ...         ...          ...      ...       ...
# 631               RB   Vikings        2001           27    397.0    5961.0
# 632               DB   Raiders        2001           28    479.0    5776.0
# 633               DE      Rams        2001           29    540.0    7075.0
# 634               WR     Colts        2001           30    429.0    6141.0
# 635               TE    Ravens        2001           31    333.0    5014.0
#
#      Team Ply  Team Y/P  Team TO  Team FL  ...  Def. Rank Yds.3  \
# 0      1049.0       4.9     30.0     14.0  ...              NaN
# 1       885.0       5.0     21.0      8.0  ...              NaN
# 2      1021.0       5.4     23.0      8.0  ...              NaN
# 3      1012.0       5.4     33.0     16.0  ...              NaN
# 4      1022.0       4.9     26.0      8.0  ...              NaN
# ..        ...       ...      ...      ...  ...              ...
# 631     958.0       6.2     28.0     10.0  ...              NaN
# 632    1023.0       5.6     20.0      9.0  ...              NaN
# 633    1014.0       7.0     35.0     12.0  ...              NaN
# 634    1026.0       6.0     29.0     14.0  ...              NaN
# 635    1058.0       4.7     26.0      7.0  ...              NaN
#
#      Def. Rank 1stPy  Def. Rank #Dr  Def. Rank Sc%  Def. Rank TO%  \
# 0                NaN            NaN            9.0           27.0
# 1                NaN            NaN            4.0           15.0
# 2                NaN            NaN            7.0           25.0
# 3                NaN            NaN            8.0           29.0
# 4                NaN            NaN            1.0           28.0
# ..               ...            ...            ...            ...
# 631              NaN            NaN            6.0           31.0
# 632              NaN            NaN           24.0            7.0
# 633              NaN            NaN            2.0           22.0
# 634              NaN            NaN           12.0           23.0
# 635              NaN            NaN           31.0            1.0
#
#      Def. Rank Start  Def. Rank Time  Def. Rank Plays  Def. Rank Yds.4  \
# 0               12.0            18.0             15.0             28.0
# 1               31.0            31.0             29.0             29.0
# 2                3.0            21.0             28.0             30.0
# 3               25.0            19.0             17.0             20.0
# 4               27.0            20.0             20.0             26.0
# ..               ...             ...              ...              ...
# 631              7.0            30.0             30.0             30.0
# 632              1.0             5.0             15.0             18.0
# 633             25.0            15.0             14.0             24.0
# 634              3.0            25.0             28.0             25.0
# 635              2.0             1.0              1.0              2.0
#
#      Def. Rank Pts
# 0             22.0
# 1             30.0
# 2             24.0
# 3             25.0
# 4             32.0
# ..             ...
# 631           27.0
# 632           11.0
# 633           30.0
# 634           19.0
# 635            1.0
#
# [636 rows x 124 columns]

# %%
# Data Cleaning
def clean_raw_df(raw, save, keep_id) -> 'DataFrame':
    
    # Convert non-Numerical data types to Numerical
    raw = _convert_string_data(raw)
    
    # Keep only the columns of data that we want
    raw = _isolate_key_columns(raw)
    
    # Create an ID column for later reference
    raw = _add_id_column(raw)
    
    # Save a copy for reference to identify what team/position/year occurred for stats
    if save:
        _save_reference_df(raw)
    
    # Remove Identifying Columns
    if keep_id == False:
        raw = _remove_id_columns(raw)
    
    return raw

def _convert_string_data(df) -> 'DataFrame':
    team_start_list = []
    opp_start_list = []
    for i in list(df['Team Start']):
        team_start_list.append(float(str(i)[4:].strip()))
    for i in list(df['Opp. Start']):
        opp_start_list.append(float(str(i)[4:].strip()))
    
    df['Team Start'] = team_start_list
    df['Opp. Start'] = opp_start_list
    
    team_time_list = []
    opp_time_list = []
    for i in list(df['Team Time']):
        team_time_list.append(float((int(str(i)[0])*60)+int(str(i)[2:])))
    for i in list(df['Opp. Time']):
        opp_time_list.append(float((int(str(i)[0])*60)+int(str(i)[2:])))
        
    df['Team Time'] = team_time_list
    df['Opp. Time'] = opp_time_list
    
    return df
    
def _isolate_key_columns(df):
    factors = BASIC_FACTORS + TEAM_FACTORS + OPP_FACTORS + OFF_RANK_FACTORS + DEF_RANK_FACTORS
    df = df[factors]
    return df

def _add_id_column(df) -> 'DataFrame':
    df = df.reset_index()
    df = df.rename(columns={'index':'ID'})
    return df
    
def _save_reference_df(df):
    reference_df = df.copy(deep=True)
    reference_df.to_csv('Clean Reference For Last ' + str(YEARS) + ' Drafts.csv', encoding = 'utf-8-sig', index=False)
    
def _remove_id_columns(df):
    df = df.drop(columns=['Position Drafted', 'Team', 'Draft Year'])
    return df

# %%
# We will use this dataframe for our model since it only has Numerical values, 
# but we will not use the ID when calculating distance
clean = clean_raw_df(raw, True, False)
clean
# Out:
#       ID  Pick Number  Team PF  Team TO  Team Att  Team Yds.1  Team TD  \
# 0      0            1    279.0     30.0     616.0      3652.0     18.0
# 1      1            2    266.0     21.0     479.0      2812.0     18.0
# 2      2            3    341.0     23.0     571.0      3900.0     28.0
# 3      3            4    341.0     33.0     607.0      3731.0     30.0
# 4      4            5    306.0     26.0     615.0      3804.0     22.0
# ..   ...          ...      ...      ...       ...         ...      ...
# 631  631           27    397.0     28.0     495.0      3832.0     33.0
# 632  632           28    479.0     20.0     475.0      3306.0     28.0
# 633  633           29    540.0     35.0     587.0      5232.0     37.0
# 634  634           30    429.0     29.0     571.0      4282.0     33.0
# 635  635           31    333.0     26.0     504.0      2815.0     20.0
#
#      Team Int  Team Att.1  Team Yds.2  ...  Opp. Y/A  Opp. 1stD.2  \
# 0        16.0       385.0      1517.0  ...       4.7        124.0
# 1        13.0       356.0      1583.0  ...       4.7        120.0
# 2        15.0       407.0      1649.0  ...       4.1         94.0
# 3        17.0       362.0      1685.0  ...       3.9        100.0
# 4        18.0       349.0      1156.0  ...       4.5        113.0
# ..        ...         ...         ...  ...       ...          ...
# 631      18.0       428.0      2129.0  ...       4.5        110.0
# 632      11.0       520.0      2470.0  ...       4.0         85.0
# 633      23.0       383.0      1843.0  ...       4.4         95.0
# 634      15.0       435.0      1859.0  ...       4.3        109.0
# 635      19.0       511.0      2199.0  ...       2.7         59.0
#
#      Off. Rank PF  Off. Rank Yds.1  Off. Rank TO  Off. Rank Att  Def. Rank PF  \
# 0            30.0             19.0          27.0            6.0          25.0
# 1            32.0             32.0          16.0           28.0          27.0
# 2            18.0             10.0          19.0           17.0          26.0
# 3            18.0             18.0          30.0            9.0          30.0
# 4            25.0             12.0          25.0            7.0          32.0
# ..            ...              ...           ...            ...           ...
# 631           5.0              7.0          13.0           23.0          24.0
# 632           3.0             15.0           2.0           25.0           9.0
# 633           1.0              1.0          24.0            3.0          31.0
# 634           4.0              2.0          15.0            8.0          15.0
# 635          14.0             22.0           9.0           20.0           1.0
#
#      Def. Rank Yds.1  Def. Rank TO  Def. Rank Att
# 0               21.0          28.0            2.0
# 1               18.0          15.0           11.0
# 2               32.0          24.0           31.0
# 3               28.0          28.0           17.0
# 4               26.0          28.0           14.0
# ..               ...           ...            ...
# 631             28.0          31.0           28.0
# 632             25.0           7.0           30.0
# 633             27.0          20.0           17.0
# 634             18.0          25.0           14.0
# 635              8.0           1.0           13.0
#
# [636 rows x 32 columns]

# %%
# We will use this dataframe to reference the Team/Year/Position Drafted for our test values and our test's closest neighbors
reference = pd.read_csv('Clean Reference For Last ' + str(YEARS) + ' Drafts.csv', encoding = 'utf-8')
reference
# Out:
#       ID Position Drafted      Team  Draft Year  Pick Number  Team PF  \
# 0      0               QB   Bengals        2020            1    279.0
# 1      1               DE  Redskins        2020            2    266.0
# 2      2               DB     Lions        2020            3    341.0
# 3      3                T    Giants        2020            4    341.0
# 4      4               QB  Dolphins        2020            5    306.0
# ..   ...              ...       ...         ...          ...      ...
# 631  631               RB   Vikings        2001           27    397.0
# 632  632               DB   Raiders        2001           28    479.0
# 633  633               DE      Rams        2001           29    540.0
# 634  634               WR     Colts        2001           30    429.0
# 635  635               TE    Ravens        2001           31    333.0
#
#      Team TO  Team Att  Team Yds.1  Team TD  ...  Opp. Y/A  Opp. 1stD.2  \
# 0       30.0     616.0      3652.0     18.0  ...       4.7        124.0
# 1       21.0     479.0      2812.0     18.0  ...       4.7        120.0
# 2       23.0     571.0      3900.0     28.0  ...       4.1         94.0
# 3       33.0     607.0      3731.0     30.0  ...       3.9        100.0
# 4       26.0     615.0      3804.0     22.0  ...       4.5        113.0
# ..       ...       ...         ...      ...  ...       ...          ...
# 631     28.0     495.0      3832.0     33.0  ...       4.5        110.0
# 632     20.0     475.0      3306.0     28.0  ...       4.0         85.0
# 633     35.0     587.0      5232.0     37.0  ...       4.4         95.0
# 634     29.0     571.0      4282.0     33.0  ...       4.3        109.0
# 635     26.0     504.0      2815.0     20.0  ...       2.7         59.0
#
#      Off. Rank PF  Off. Rank Yds.1  Off. Rank TO  Off. Rank Att  Def. Rank PF  \
# 0            30.0             19.0          27.0            6.0          25.0
# 1            32.0             32.0          16.0           28.0          27.0
# 2            18.0             10.0          19.0           17.0          26.0
# 3            18.0             18.0          30.0            9.0          30.0
# 4            25.0             12.0          25.0            7.0          32.0
# ..            ...              ...           ...            ...           ...
# 631           5.0              7.0          13.0           23.0          24.0
# 632           3.0             15.0           2.0           25.0           9.0
# 633           1.0              1.0          24.0            3.0          31.0
# 634           4.0              2.0          15.0            8.0          15.0
# 635          14.0             22.0           9.0           20.0           1.0
#
#      Def. Rank Yds.1  Def. Rank TO  Def. Rank Att
# 0               21.0          28.0            2.0
# 1               18.0          15.0           11.0
# 2               32.0          24.0           31.0
# 3               28.0          28.0           17.0
# 4               26.0          28.0           14.0
# ..               ...           ...            ...
# 631             28.0          31.0           28.0
# 632             25.0           7.0           30.0
# 633             27.0          20.0           17.0
# 634             18.0          25.0           14.0
# 635              8.0           1.0           13.0
#
# [636 rows x 35 columns]

# %%
# Split into Train / Test Dataframes to Test Model Accuracy on 2020 NFL Draft

def split_dfs_for_testing(final_df) -> list:

    test_df = final_df.iloc[:32]
    train_df = final_df.iloc[32:]
    print(train_df.shape, test_df.shape)

    combine = [train_df, test_df]
    return combine

# %%
combine = split_dfs_for_testing(clean)
train_df_1 = combine[0]
test_df_1 = combine[1]
train_df_1.to_csv('Train Data For ' + str(CURRENT_YEAR) + ' Draft.csv', encoding = 'utf-8-sig', index=False)
test_df_1.to_csv('Test Data For ' + str(CURRENT_YEAR) + ' Draft.csv', encoding = 'utf-8-sig', index=False)
train_df_1
# Out:
# (604, 32) (32, 32)
#       ID  Pick Number  Team PF  Team TO  Team Att  Team Yds.1  Team TD  \
# 32    32            1    225.0     28.0     495.0      2523.0     15.0
# 33    33            2    342.0     32.0     532.0      3867.0     26.0
# 34    34            3    333.0     30.0     524.0      3165.0     18.0
# 35    35            4    290.0     24.0     556.0      3751.0     19.0
# 36    36            5    396.0     35.0     625.0      5125.0     36.0
# ..   ...          ...      ...      ...       ...         ...      ...
# 631  631           27    397.0     28.0     495.0      3832.0     33.0
# 632  632           28    479.0     20.0     475.0      3306.0     28.0
# 633  633           29    540.0     35.0     587.0      5232.0     37.0
# 634  634           30    429.0     29.0     571.0      4282.0     33.0
# 635  635           31    333.0     26.0     504.0      2815.0     20.0
#
#      Team Int  Team Att.1  Team Yds.2  ...  Opp. Y/A  Opp. 1stD.2  \
# 32       18.0       355.0      1342.0  ...       4.9        139.0
# 33       20.0       423.0      1902.0  ...       4.1        104.0
# 34       19.0       410.0      1622.0  ...       4.6        104.0
# 35       10.0       387.0      1628.0  ...       4.7        108.0
# 36       26.0       389.0      1523.0  ...       4.7        122.0
# ..        ...         ...         ...  ...       ...          ...
# 631      18.0       428.0      2129.0  ...       4.5        110.0
# 632      11.0       520.0      2470.0  ...       4.0         85.0
# 633      23.0       383.0      1843.0  ...       4.4         95.0
# 634      15.0       435.0      1859.0  ...       4.3        109.0
# 635      19.0       511.0      2199.0  ...       2.7         59.0
#
#      Off. Rank PF  Off. Rank Yds.1  Off. Rank TO  Off. Rank Att  Def. Rank PF  \
# 32           32.0             32.0          27.0           29.0          26.0
# 33           21.0             15.0          30.0           20.0          28.0
# 34           23.0             25.0          29.0           22.0          29.0
# 35           28.0             18.0          22.0           16.0          32.0
# 36           12.0              1.0          32.0            4.0          31.0
# ..            ...              ...           ...            ...           ...
# 631           5.0              7.0          13.0           23.0          24.0
# 632           3.0             15.0           2.0           25.0           9.0
# 633           1.0              1.0          24.0            3.0          31.0
# 634           4.0              2.0          15.0            8.0          15.0
# 635          14.0             22.0           9.0           20.0           1.0
#
#      Def. Rank Yds.1  Def. Rank TO  Def. Rank Att
# 32               4.0          28.0            6.0
# 33              11.0          32.0           14.0
# 34              24.0          16.0           24.0
# 35              19.0          22.0            1.0
# 36              26.0          22.0           12.0
# ..               ...           ...            ...
# 631             28.0          31.0           28.0
# 632             25.0           7.0           30.0
# 633             27.0          20.0           17.0
# 634             18.0          25.0           14.0
# 635              8.0           1.0           13.0
#
# [604 rows x 32 columns]

# %%
test_df_1
# Out:
#     ID  Pick Number  Team PF  Team TO  Team Att  Team Yds.1  Team TD  \
# 0    0            1    279.0     30.0     616.0      3652.0     18.0
# 1    1            2    266.0     21.0     479.0      2812.0     18.0
# 2    2            3    341.0     23.0     571.0      3900.0     28.0
# 3    3            4    341.0     33.0     607.0      3731.0     30.0
# 4    4            5    306.0     26.0     615.0      3804.0     22.0
# 5    5            6    337.0     31.0     597.0      4426.0     24.0
# 6    6            7    340.0     35.0     633.0      3650.0     17.0
# 7    7            8    361.0     18.0     554.0      3477.0     20.0
# 8    8            9    300.0     20.0     589.0      3760.0     24.0
# 9    9           10    335.0     28.0     539.0      3554.0     22.0
# 10  10           11    276.0     25.0     521.0      3111.0     19.0
# 11  11           12    313.0     17.0     523.0      3926.0     22.0
# 12  12           13    458.0     41.0     630.0      4845.0     33.0
# 13  13           14    479.0     23.0     478.0      3792.0     28.0
# 14  14           15    282.0     16.0     504.0      3115.0     16.0
# 15  15           16    381.0     25.0     684.0      4714.0     29.0
# 16  16           17    434.0     18.0     597.0      4751.0     30.0
# 17  17           18    306.0     26.0     615.0      3804.0     22.0
# 18  18           19    313.0     17.0     523.0      3926.0     22.0
# 19  19           20    300.0     20.0     589.0      3760.0     24.0
# 20  20           21    385.0     23.0     613.0      3833.0     27.0
# 21  21           22    407.0     20.0     466.0      3523.0     26.0
# 22  22           23    337.0     31.0     597.0      4426.0     24.0
# 23  23           24    458.0      8.0     581.0      4244.0     36.0
# 24  24           25    479.0     23.0     478.0      3792.0     28.0
# 25  25           26    376.0     13.0     573.0      3733.0     26.0
# 26  26           27    405.0     20.0     517.0      3791.0     31.0
# 27  27           28    531.0     15.0     440.0      3225.0     37.0
# 28  28           29    402.0     17.0     448.0      3582.0     29.0
# 29  29           30    306.0     26.0     615.0      3804.0     22.0
# 30  30           31    407.0     20.0     466.0      3523.0     26.0
# 31  31           32    451.0     15.0     576.0      4498.0     30.0
#
#     Team Int  Team Att.1  Team Yds.2  ...  Opp. Y/A  Opp. 1stD.2  \
# 0       16.0       385.0      1517.0  ...       4.7        124.0
# 1       13.0       356.0      1583.0  ...       4.7        120.0
# 2       15.0       407.0      1649.0  ...       4.1         94.0
# 3       17.0       362.0      1685.0  ...       3.9        100.0
# 4       18.0       349.0      1156.0  ...       4.5        113.0
# 5       20.0       366.0      1453.0  ...       4.2        101.0
# 6       21.0       386.0      1819.0  ...       5.2        128.0
# 7       12.0       396.0      1990.0  ...       4.4         94.0
# 8        8.0       389.0      1708.0  ...       5.1        114.0
# 9       21.0       393.0      1901.0  ...       5.0        124.0
# 10      16.0       383.0      1257.0  ...       3.3         75.0
# 11       8.0       437.0      1893.0  ...       3.9         91.0
# 12      30.0       409.0      1521.0  ...       3.3         70.0
# 13      13.0       498.0      2305.0  ...       4.5        105.0
# 14      10.0       409.0      1662.0  ...       4.2         96.0
# 15      15.0       362.0      1361.0  ...       4.2        108.0
# 16      11.0       449.0      2153.0  ...       4.1        101.0
# 17      18.0       349.0      1156.0  ...       4.5        113.0
# 18       8.0       437.0      1893.0  ...       3.9         91.0
# 19       8.0       389.0      1708.0  ...       5.1        114.0
# 20       8.0       454.0      1939.0  ...       4.1         76.0
# 21       8.0       476.0      2133.0  ...       4.3         78.0
# 22      20.0       366.0      1453.0  ...       4.2        101.0
# 23       6.0       405.0      1738.0  ...       4.2         71.0
# 24      13.0       498.0      2305.0  ...       4.5        105.0
# 25       4.0       411.0      1795.0  ...       4.7         99.0
# 26       6.0       481.0      2200.0  ...       4.9         97.0
# 27       8.0       596.0      3296.0  ...       4.4         74.0
# 28       8.0       445.0      2223.0  ...       4.0         95.0
# 29      18.0       349.0      1156.0  ...       4.5        113.0
# 30       8.0       476.0      2133.0  ...       4.3         78.0
# 31       5.0       375.0      1569.0  ...       4.9        115.0
#
#     Off. Rank PF  Off. Rank Yds.1  Off. Rank TO  Off. Rank Att  Def. Rank PF  \
# 0           30.0             19.0          27.0            6.0          25.0
# 1           32.0             32.0          16.0           28.0          27.0
# 2           18.0             10.0          19.0           17.0          26.0
# 3           18.0             18.0          30.0            9.0          30.0
# 4           25.0             12.0          25.0            7.0          32.0
# 5           21.0              6.0          29.0           10.0          14.0
# 6           20.0             20.0          31.0            2.0          31.0
# 7           16.0             24.0           9.0           18.0          28.0
# 8           26.0             16.0          13.0           12.0          21.0
# 9           22.0             22.0          26.0           19.0          20.0
# 10          31.0             29.0          23.0           22.0          16.0
# 11          24.0              9.0           7.0           21.0          24.0
# 12           3.0              1.0          32.0            4.0          29.0
# 13           2.0             13.0          19.0           29.0           8.0
# 14          28.0             28.0           6.0           27.0          10.0
# 15          13.0              3.0          23.0            1.0          23.0
# 16           6.0              2.0           9.0           10.0          11.0
# 17          25.0             12.0          25.0            7.0          32.0
# 18          24.0              9.0           7.0           21.0          24.0
# 19          26.0             16.0          13.0           12.0          21.0
# 20          12.0             11.0          19.0            8.0          15.0
# 21           8.0             23.0          13.0           30.0           5.0
# 22          21.0              6.0          29.0           10.0          14.0
# 23           3.0              7.0           1.0           13.0          13.0
# 24           2.0             13.0          19.0           29.0           8.0
# 25          15.0             17.0           2.0           16.0           9.0
# 26           9.0             14.0          13.0           23.0          22.0
# 27           1.0             27.0           3.0           32.0           3.0
# 28          10.0             21.0           7.0           31.0          12.0
# 29          25.0             12.0          25.0            7.0          32.0
# 30           8.0             23.0          13.0           30.0           5.0
# 31           5.0              5.0           3.0           15.0           7.0
#
#     Def. Rank Yds.1  Def. Rank TO  Def. Rank Att
# 0              21.0          28.0            2.0
# 1              18.0          15.0           11.0
# 2              32.0          24.0           31.0
# 3              28.0          28.0           17.0
# 4              26.0          28.0           14.0
# 5               5.0          32.0            1.0
# 6              13.0          17.0           12.0
# 7              31.0          25.0           28.0
# 8              16.0          22.0            5.0
# 9               7.0          19.0            3.0
# 10             17.0          17.0           24.0
# 11             25.0          31.0            7.0
# 12             30.0           5.0           32.0
# 13              1.0           6.0            6.0
# 14             11.0          25.0           10.0
# 15             22.0          19.0            8.0
# 16             10.0          25.0           20.0
# 17             26.0          28.0           14.0
# 18             25.0          31.0            7.0
# 19             16.0          22.0            5.0
# 20             19.0          19.0           21.0
# 21             15.0           4.0           28.0
# 22              5.0          32.0            1.0
# 23             20.0          10.0           30.0
# 24              1.0           6.0            6.0
# 25             14.0           7.0           15.0
# 26             27.0           3.0           26.0
# 27              6.0           7.0           12.0
# 28             24.0          10.0           26.0
# 29             26.0          28.0           14.0
# 30             15.0           4.0           28.0
# 31              8.0          10.0           23.0
#
# [32 rows x 32 columns]

# %%
# DATA PREPARATION FUNCTIONS

def convert_df_to_weighted_df(df):
    std_list = list(df.std(axis = 0, skipna= True))
    mean_list = list(df.mean(axis=0, skipna= True))
    frames = [pd.DataFrame(df.loc[df.index[0]], columns=df.columns)]
    for i in range(df.index[0], df.index[0]+len(df.index)):
        row_list = list(df.loc[i])
        weighted_row = []
        for j in range(len(row_list)):
            if j == 0:
                weighted_row.append(row_list[j])
            else:
                weighted_row.append((row_list[j] - mean_list[j])/std_list[j])
        weighted_df_row = pd.DataFrame([weighted_row], columns=df.columns)
        frames.append(weighted_df_row)
    weighted_df = pd.concat(frames)
    weighted_df.index = df.index
    return weighted_df

def ready_dataset_for_modeling(train_df, test_df) -> list:
    weighted_train_df = convert_df_to_weighted_df(train_df)
    weighted_test_df = convert_df_to_weighted_df(test_df)
    
    train_dataset = weighted_train_df.to_numpy().tolist()
    test_dataset = weighted_test_df.to_numpy().tolist()
    
    combine = [train_dataset, test_dataset]
    return combine

# %%
model_ready_combine = ready_dataset_for_modeling(train_df_1, test_df_1)
train_dataset_1 = model_ready_combine[0]
test_dataset_1 = model_ready_combine[1]

# %%
# K NEAREST NEIGHBORS MODEL FUNCTIONS

def euclidean_distance(row1, row2):
    distance = 0.0
    for i in range(1, len(row1)-1):
        distance += (row1[i] - row2[i])**2
    return math.sqrt(distance)

def get_neighbors(train, test_row, num_neighbors):
    distances = list()
    for i in range(0, len(train)-1):
        ID = train[i][0]
        train_row = train[i]
        dist = euclidean_distance(test_row, train_row)
        distances.append((train_row, dist, ID))
    distances.sort(key=lambda tup: tup[1])
    neighbors = list()
    for i in range(num_neighbors):
        neighbors.append((distances[i][2], round(distances[i][1], 2)))
    return neighbors

def prediction_data(train_dataset, test_dataset, test_row_index, reference_df) -> 'DataFrame':
    neighbors = get_neighbors(train_dataset, test_dataset[test_row_index], NUM_NEIGHBORS)
    
    ID = test_dataset[test_row_index][0]
    frames = []
    id_col = [ID]
    distance_col = [0]
    
    for neighbor in neighbors:
        id_col.append(neighbor[0])
        distance_col.append(neighbor[1])
        frames.append(pd.DataFrame([list(reference_df.loc[int(neighbor[0])])], columns=reference_df.columns))
        
    big_df = pd.concat(frames)
    big_df = pd.DataFrame([reference_df.loc[ID]], columns=reference_df.columns).append(big_df, ignore_index=True)
    big_df.insert(1, 'Unit', big_df['Position Drafted'].map(UNIT_DICT), True)
    big_df.insert(1, 'Distance', distance_col, True)
    
    return big_df

def unit_prediction(train_dataset, test_dataset, test_row_index, reference_df):
    predict_dict = {}
    neighbors = get_neighbors(train_dataset, test_dataset[test_row_index], NUM_NEIGHBORS)
    ID = test_dataset[test_row_index][0]
    
    sum = 0
    for neighbor in neighbors:
        position = list(reference_df.loc[int(neighbor[0])])[1]
        for i in UNIT_DICT.keys():
            if position == i:
                unit = UNIT_DICT[position]
        if unit not in predict_dict:
            predict_dict[unit] = 0
        predict_dict[unit] += 1
        sum += 1
    
    percent_dict = {'OFF':0,'DEF':0,'Predicted':'NA','Actual':'NA'}
    for i in predict_dict:
        percent_dict[i] = round(predict_dict[i]/sum, 4)*100
        
    if percent_dict['OFF'] > percent_dict['DEF']:
        percent_dict['Predicted'] = 'OFF'
    else:
        percent_dict['Predicted'] = 'DEF'
        
    try:
        percent_dict['Actual'] = UNIT_DICT[list(reference_df.loc[ID])[1]]
    except:
        percent_dict['Actual'] = 'NA'
        
    return percent_dict

# %%
# Test Closest Neighbors for Number 1 Pick of the 2020 NFL DRAFT
# In other words, out of the past 20 years, which Team Stats are the closest to the Bengals 2019 Season, 
# and what unit did That Team draft their following year?
PICK_NUM = 1
test = prediction_data(train_dataset_1, test_dataset_1, PICK_NUM-1, reference)
test
# Out:
#     ID  Distance Unit Position Drafted        Team  Draft Year  Pick Number  \
# 0    0      0.00  OFF               QB     Bengals        2020            1
# 1  576      3.27  OFF                T       Bills        2002            4
# 2  224      3.39  OFF                T     Jaguars        2013            2
# 3  417      3.44  DEF               DE  Buccaneers        2007            4
# 4  478      3.45  OFF               QB       49ers        2005            1
# 5  255      3.46  OFF               QB       Colts        2012            1
#
#    Team PF  Team TO  Team Att  ...  Opp. Y/A  Opp. 1stD.2  Off. Rank PF  \
# 0    279.0     30.0     616.0  ...       4.7        124.0          30.0
# 1    265.0     33.0     557.0  ...       4.4        122.0          27.0
# 2    255.0     26.0     586.0  ...       4.1        133.0          30.0
# 3    211.0     32.0     535.0  ...       3.9        108.0          31.0
# 4    259.0     40.0     561.0  ...       4.0        121.0          30.0
# 5    243.0     29.0     534.0  ...       4.3        136.0          28.0
#
#    Off. Rank Yds.1  Off. Rank TO  Off. Rank Att  Def. Rank PF  \
# 0             19.0          27.0            6.0          25.0
# 1             12.0          19.0            7.0          29.0
# 2             21.0          17.0           11.0          29.0
# 3             26.0          23.0           11.0          21.0
# 4             20.0          30.0            6.0          32.0
# 5             27.0          23.0           21.0          28.0
#
#    Def. Rank Yds.1  Def. Rank TO  Def. Rank Att
# 0             21.0          28.0            2.0
# 1             13.0          30.0            2.0
# 2             22.0          18.0            9.0
# 3             19.0          30.0            6.0
# 4             19.0          27.0            8.0
# 5             15.0          30.0            7.0
#
# [6 rows x 37 columns]

# %%
# What percentage of the k-nearest neighbors drafted OFF vs. DEF, and what was the actual drafted for the test?
unit_prediction(train_dataset_1, test_dataset_1, PICK_NUM-1, reference)
# Out:
# {'OFF': 80.0, 'DEF': 20.0, 'Predicted': 'OFF', 'Actual': 'OFF'}

# %%
# MODEL TESTING FUNCTIONS

def test_unit_prediction(train_dataset, test_dataset, reference_df):
    correct_predictions = 0
    eighty_plus_percent_correct = 0
    total_eighty = 0
    print(list(reference_df.loc[test_dataset[0][0]])[3])
    
    length = len(test_dataset)
    for i in range(length):
        predict_dict = unit_prediction(train_dataset, test_dataset, i, reference_df)
        if predict_dict['Actual'] == predict_dict['Predicted']:
            correct_predictions += 1
            if predict_dict[predict_dict['Predicted']] >= 80:
                eighty_plus_percent_correct += 1
        if predict_dict[predict_dict['Predicted']] >= 80:
            total_eighty += 1
        print(predict_dict, 'Total ' + str(correct_predictions)+'/'+str(i+1))
        
    correct_pred_percent = round(correct_predictions/length, 4)
    eighty_plus_percent_accuracy = round(eighty_plus_percent_correct / total_eighty, 4)
    
    print()
    print('Correct Predictions %: ', correct_pred_percent)
    print('Correct 80+% Predictions %: ', eighty_plus_percent_accuracy)
    print()
    
    return (correct_pred_percent, eighty_plus_percent_accuracy)

def test_model_across_past_years(train_df, test_df, reference_df, years):
    total_correct = 0
    total_eighty_correct = 0
    train = train_df.copy(deep=True)
    test = test_df.copy(deep=True)
    for i in range(years):
        model_ready_combine = ready_dataset_for_modeling(train, test)
        train_dataset = model_ready_combine[0]
        test_dataset = model_ready_combine[1]
        predict = test_unit_prediction(train_dataset, test_dataset, reference_df)
        total_correct += predict[0]
        total_eighty_correct += predict[1]
        test = train.iloc[:32]
        train = train.drop(train.head(32).index)
        
    average_correct = round(total_correct / years, 4)*100
    average_eighty_correct = round(total_eighty_correct / years, 4)*100
    
    print('Average Correct Predictions %: ', average_correct)
    print('Average Correct 80+% Predictions %: ', average_eighty_correct)
    return (average_correct, average_eighty_correct)

# %%
# Out of 32 Picks for the 2020 NFL Draft, what percentage of them are correctly predicted 
# using data from the 5 Nearest Neighbors?
test_unit_prediction(train_dataset_1, test_dataset_1, reference)
# Out:
# 2020
# {'OFF': 80.0, 'DEF': 20.0, 'Predicted': 'OFF', 'Actual': 'OFF'} Total 1/1
# {'OFF': 40.0, 'DEF': 60.0, 'Predicted': 'DEF', 'Actual': 'DEF'} Total 2/2
# {'OFF': 40.0, 'DEF': 60.0, 'Predicted': 'DEF', 'Actual': 'DEF'} Total 3/3
# {'OFF': 80.0, 'DEF': 20.0, 'Predicted': 'OFF', 'Actual': 'OFF'} Total 4/4
# {'OFF': 100.0, 'DEF': 0, 'Predicted': 'OFF', 'Actual': 'OFF'} Total 5/5
# {'OFF': 80.0, 'DEF': 20.0, 'Predicted': 'OFF', 'Actual': 'OFF'} Total 6/6
# {'OFF': 40.0, 'DEF': 60.0, 'Predicted': 'DEF', 'Actual': 'DEF'} Total 7/7
# {'OFF': 20.0, 'DEF': 80.0, 'Predicted': 'DEF', 'Actual': 'DEF'} Total 8/8
# {'OFF': 20.0, 'DEF': 80.0, 'Predicted': 'DEF', 'Actual': 'DEF'} Total 9/9
# {'OFF': 40.0, 'DEF': 60.0, 'Predicted': 'DEF', 'Actual': 'OFF'} Total 9/10
# {'OFF': 60.0, 'DEF': 40.0, 'Predicted': 'OFF', 'Actual': 'OFF'} Total 10/11
# {'OFF': 40.0, 'DEF': 60.0, 'Predicted': 'DEF', 'Actual': 'OFF'} Total 10/12
# {'OFF': 60.0, 'DEF': 40.0, 'Predicted': 'OFF', 'Actual': 'OFF'} Total 11/13
# {'OFF': 40.0, 'DEF': 60.0, 'Predicted': 'DEF', 'Actual': 'DEF'} Total 12/14
# {'OFF': 20.0, 'DEF': 80.0, 'Predicted': 'DEF', 'Actual': 'OFF'} Total 12/15
# {'OFF': 0, 'DEF': 100.0, 'Predicted': 'DEF', 'Actual': 'DEF'} Total 13/16
# {'OFF': 80.0, 'DEF': 20.0, 'Predicted': 'OFF', 'Actual': 'OFF'} Total 14/17
# {'OFF': 80.0, 'DEF': 20.0, 'Predicted': 'OFF', 'Actual': 'OFF'} Total 15/18
# {'OFF': 20.0, 'DEF': 80.0, 'Predicted': 'DEF', 'Actual': 'DEF'} Total 16/19
# {'OFF': 20.0, 'DEF': 80.0, 'Predicted': 'DEF', 'Actual': 'DEF'} Total 17/20
# {'OFF': 60.0, 'DEF': 40.0, 'Predicted': 'OFF', 'Actual': 'OFF'} Total 18/21
# {'OFF': 60.0, 'DEF': 40.0, 'Predicted': 'OFF', 'Actual': 'OFF'} Total 19/22
# {'OFF': 60.0, 'DEF': 40.0, 'Predicted': 'OFF', 'Actual': 'DEF'} Total 19/23
# {'OFF': 0, 'DEF': 100.0, 'Predicted': 'DEF', 'Actual': 'OFF'} Total 19/24
# {'OFF': 60.0, 'DEF': 40.0, 'Predicted': 'OFF', 'Actual': 'OFF'} Total 20/25
# {'OFF': 80.0, 'DEF': 20.0, 'Predicted': 'OFF', 'Actual': 'OFF'} Total 21/26
# {'OFF': 20.0, 'DEF': 80.0, 'Predicted': 'DEF', 'Actual': 'DEF'} Total 22/27
# {'OFF': 60.0, 'DEF': 40.0, 'Predicted': 'OFF', 'Actual': 'DEF'} Total 22/28
# {'OFF': 40.0, 'DEF': 60.0, 'Predicted': 'DEF', 'Actual': 'OFF'} Total 22/29
# {'OFF': 80.0, 'DEF': 20.0, 'Predicted': 'OFF', 'Actual': 'DEF'} Total 22/30
# {'OFF': 60.0, 'DEF': 40.0, 'Predicted': 'OFF', 'Actual': 'DEF'} Total 22/31
# {'OFF': 40.0, 'DEF': 60.0, 'Predicted': 'DEF', 'Actual': 'OFF'} Total 22/32
#
# Correct Predictions %:  0.6875
# Correct 80+% Predictions %:  0.8125
# (0.6875, 0.8125)

# %%
# Now we can begin testing the model for drafts before the 2020 draft
# For example, we will test the average scores of the model by also predicting the 2019 Draft using draft data from 2001-2018
# And to test the 2018 Draft, we will use draft data from 2001-2017
test_model_across_past_years(train_df_1, test_df_1, reference, 2)
# Out:
# 2020
# {'OFF': 80.0, 'DEF': 20.0, 'Predicted': 'OFF', 'Actual': 'OFF'} Total 1/1
# {'OFF': 40.0, 'DEF': 60.0, 'Predicted': 'DEF', 'Actual': 'DEF'} Total 2/2
# {'OFF': 40.0, 'DEF': 60.0, 'Predicted': 'DEF', 'Actual': 'DEF'} Total 3/3
# {'OFF': 80.0, 'DEF': 20.0, 'Predicted': 'OFF', 'Actual': 'OFF'} Total 4/4
# {'OFF': 100.0, 'DEF': 0, 'Predicted': 'OFF', 'Actual': 'OFF'} Total 5/5
# {'OFF': 80.0, 'DEF': 20.0, 'Predicted': 'OFF', 'Actual': 'OFF'} Total 6/6
# {'OFF': 40.0, 'DEF': 60.0, 'Predicted': 'DEF', 'Actual': 'DEF'} Total 7/7
# {'OFF': 20.0, 'DEF': 80.0, 'Predicted': 'DEF', 'Actual': 'DEF'} Total 8/8
# {'OFF': 20.0, 'DEF': 80.0, 'Predicted': 'DEF', 'Actual': 'DEF'} Total 9/9
# {'OFF': 40.0, 'DEF': 60.0, 'Predicted': 'DEF', 'Actual': 'OFF'} Total 9/10
# {'OFF': 60.0, 'DEF': 40.0, 'Predicted': 'OFF', 'Actual': 'OFF'} Total 10/11
# {'OFF': 40.0, 'DEF': 60.0, 'Predicted': 'DEF', 'Actual': 'OFF'} Total 10/12
# {'OFF': 60.0, 'DEF': 40.0, 'Predicted': 'OFF', 'Actual': 'OFF'} Total 11/13
# {'OFF': 40.0, 'DEF': 60.0, 'Predicted': 'DEF', 'Actual': 'DEF'} Total 12/14
# {'OFF': 20.0, 'DEF': 80.0, 'Predicted': 'DEF', 'Actual': 'OFF'} Total 12/15
# {'OFF': 0, 'DEF': 100.0, 'Predicted': 'DEF', 'Actual': 'DEF'} Total 13/16
# {'OFF': 80.0, 'DEF': 20.0, 'Predicted': 'OFF', 'Actual': 'OFF'} Total 14/17
# {'OFF': 80.0, 'DEF': 20.0, 'Predicted': 'OFF', 'Actual': 'OFF'} Total 15/18
# {'OFF': 20.0, 'DEF': 80.0, 'Predicted': 'DEF', 'Actual': 'DEF'} Total 16/19
# {'OFF': 20.0, 'DEF': 80.0, 'Predicted': 'DEF', 'Actual': 'DEF'} Total 17/20
# {'OFF': 60.0, 'DEF': 40.0, 'Predicted': 'OFF', 'Actual': 'OFF'} Total 18/21
# {'OFF': 60.0, 'DEF': 40.0, 'Predicted': 'OFF', 'Actual': 'OFF'} Total 19/22
# {'OFF': 60.0, 'DEF': 40.0, 'Predicted': 'OFF', 'Actual': 'DEF'} Total 19/23
# {'OFF': 0, 'DEF': 100.0, 'Predicted': 'DEF', 'Actual': 'OFF'} Total 19/24
# {'OFF': 60.0, 'DEF': 40.0, 'Predicted': 'OFF', 'Actual': 'OFF'} Total 20/25
# {'OFF': 80.0, 'DEF': 20.0, 'Predicted': 'OFF', 'Actual': 'OFF'} Total 21/26
# {'OFF': 20.0, 'DEF': 80.0, 'Predicted': 'DEF', 'Actual': 'DEF'} Total 22/27
# {'OFF': 60.0, 'DEF': 40.0, 'Predicted': 'OFF', 'Actual': 'DEF'} Total 22/28
# {'OFF': 40.0, 'DEF': 60.0, 'Predicted': 'DEF', 'Actual': 'OFF'} Total 22/29
# {'OFF': 80.0, 'DEF': 20.0, 'Predicted': 'OFF', 'Actual': 'DEF'} Total 22/30
# {'OFF': 60.0, 'DEF': 40.0, 'Predicted': 'OFF', 'Actual': 'DEF'} Total 22/31
# {'OFF': 40.0, 'DEF': 60.0, 'Predicted': 'DEF', 'Actual': 'OFF'} Total 22/32
#
# Correct Predictions %:  0.6875
# Correct 80+% Predictions %:  0.8125
#
# 2019
# {'OFF': 60.0, 'DEF': 40.0, 'Predicted': 'OFF', 'Actual': 'OFF'} Total 1/1
# {'OFF': 40.0, 'DEF': 60.0, 'Predicted': 'DEF', 'Actual': 'DEF'} Total 2/2
# {'OFF': 40.0, 'DEF': 60.0, 'Predicted': 'DEF', 'Actual': 'DEF'} Total 3/3
# {'OFF': 60.0, 'DEF': 40.0, 'Predicted': 'OFF', 'Actual': 'DEF'} Total 3/4
# {'OFF': 40.0, 'DEF': 60.0, 'Predicted': 'DEF', 'Actual': 'DEF'} Total 4/5
# {'OFF': 20.0, 'DEF': 80.0, 'Predicted': 'DEF', 'Actual': 'OFF'} Total 4/6
# {'OFF': 80.0, 'DEF': 20.0, 'Predicted': 'OFF', 'Actual': 'DEF'} Total 4/7
# {'OFF': 80.0, 'DEF': 20.0, 'Predicted': 'OFF', 'Actual': 'OFF'} Total 5/8
# {'OFF': 60.0, 'DEF': 40.0, 'Predicted': 'OFF', 'Actual': 'DEF'} Total 5/9
# {'OFF': 20.0, 'DEF': 80.0, 'Predicted': 'DEF', 'Actual': 'DEF'} Total 6/10
# {'OFF': 60.0, 'DEF': 40.0, 'Predicted': 'OFF', 'Actual': 'OFF'} Total 7/11
# {'OFF': 60.0, 'DEF': 40.0, 'Predicted': 'OFF', 'Actual': 'DEF'} Total 7/12
# {'OFF': 60.0, 'DEF': 40.0, 'Predicted': 'OFF', 'Actual': 'DEF'} Total 7/13
# {'OFF': 40.0, 'DEF': 60.0, 'Predicted': 'DEF', 'Actual': 'OFF'} Total 7/14
# {'OFF': 40.0, 'DEF': 60.0, 'Predicted': 'DEF', 'Actual': 'OFF'} Total 7/15
# {'OFF': 40.0, 'DEF': 60.0, 'Predicted': 'DEF', 'Actual': 'DEF'} Total 8/16
# {'OFF': 20.0, 'DEF': 80.0, 'Predicted': 'DEF', 'Actual': 'DEF'} Total 9/17
# {'OFF': 80.0, 'DEF': 20.0, 'Predicted': 'OFF', 'Actual': 'OFF'} Total 10/18
# {'OFF': 60.0, 'DEF': 40.0, 'Predicted': 'OFF', 'Actual': 'DEF'} Total 10/19
# {'OFF': 20.0, 'DEF': 80.0, 'Predicted': 'DEF', 'Actual': 'OFF'} Total 10/20
# {'OFF': 80.0, 'DEF': 20.0, 'Predicted': 'OFF', 'Actual': 'DEF'} Total 10/21
# {'OFF': 60.0, 'DEF': 40.0, 'Predicted': 'OFF', 'Actual': 'OFF'} Total 11/22
# {'OFF': 40.0, 'DEF': 60.0, 'Predicted': 'DEF', 'Actual': 'OFF'} Total 11/23
# {'OFF': 80.0, 'DEF': 20.0, 'Predicted': 'OFF', 'Actual': 'OFF'} Total 12/24
# {'OFF': 40.0, 'DEF': 60.0, 'Predicted': 'DEF', 'Actual': 'OFF'} Total 12/25
# {'OFF': 60.0, 'DEF': 40.0, 'Predicted': 'OFF', 'Actual': 'DEF'} Total 12/26
# {'OFF': 80.0, 'DEF': 20.0, 'Predicted': 'OFF', 'Actual': 'DEF'} Total 12/27
# {'OFF': 60.0, 'DEF': 40.0, 'Predicted': 'OFF', 'Actual': 'DEF'} Total 12/28
# {'OFF': 20.0, 'DEF': 80.0, 'Predicted': 'DEF', 'Actual': 'DEF'} Total 13/29
# {'OFF': 0, 'DEF': 100.0, 'Predicted': 'DEF', 'Actual': 'DEF'} Total 14/30
# {'OFF': 40.0, 'DEF': 60.0, 'Predicted': 'DEF', 'Actual': 'OFF'} Total 14/31
# {'OFF': 40.0, 'DEF': 60.0, 'Predicted': 'DEF', 'Actual': 'OFF'} Total 14/32
#
# Correct Predictions %:  0.4375
# Correct 80+% Predictions %:  0.5833
#
# Average Correct Predictions %:  56.25
# Average Correct 80+% Predictions %:  69.78999999999999
# (56.25, 69.78999999999999)

# %%
# Based off of the 2020 Data we have around a 70% success rate on predicting 
# whether a team will draft an Offensive or Defensive Player in the 1st Round of the NFL Draft
# Now we will use the model for each of the team's stats in 2020 to predict the results of the 2021 NFL Draft
frames = []
for i in range(len(NEXT_DRAFT_ORDER)):
    url = get_team_stats_by_year_url(NEXT_DRAFT_ORDER[i], 2020)
    df = get_team_stats(url)
    row_df = convert_team_stats_to_one_row(df)
    final_row_df = make_team_stats_one_row(row_df, CURRENT_YEAR+1, i+1, NEXT_DRAFT_ORDER[i], None)
    frames.append(final_row_df)
test_df_2 = pd.concat(frames)
test_df_2.to_csv('Raw Data For ' + str(CURRENT_YEAR+1) + ' Draft.csv', encoding = 'utf-8-sig', index=False)
test_df_2 = pd.read_csv('Raw Data For ' + str(CURRENT_YEAR+1) + ' Draft.csv', encoding = 'utf-8')
test_df_2 = clean_raw_df(test_df_2, False, True)
test_df_2
# Out:
# Scraping https://www.pro-football-reference.com/teams/jax/2020.htm
# Scraping https://www.pro-football-reference.com/teams/nyj/2020.htm
# Scraping https://www.pro-football-reference.com/teams/mia/2020.htm
# Scraping https://www.pro-football-reference.com/teams/atl/2020.htm
# Scraping https://www.pro-football-reference.com/teams/cin/2020.htm
# Scraping https://www.pro-football-reference.com/teams/phi/2020.htm
# Scraping https://www.pro-football-reference.com/teams/det/2020.htm
# Scraping https://www.pro-football-reference.com/teams/nyg/2020.htm
# Scraping https://www.pro-football-reference.com/teams/car/2020.htm
# Scraping https://www.pro-football-reference.com/teams/den/2020.htm
# Scraping https://www.pro-football-reference.com/teams/dal/2020.htm
# Scraping https://www.pro-football-reference.com/teams/sdg/2020.htm
# Scraping https://www.pro-football-reference.com/teams/min/2020.htm
# Scraping https://www.pro-football-reference.com/teams/nwe/2020.htm
# Scraping https://www.pro-football-reference.com/teams/sfo/2020.htm
# Scraping https://www.pro-football-reference.com/teams/rai/2020.htm
# Scraping https://www.pro-football-reference.com/teams/crd/2020.htm
# Scraping https://www.pro-football-reference.com/teams/clt/2020.htm
# Scraping https://www.pro-football-reference.com/teams/was/2020.htm
# Scraping https://www.pro-football-reference.com/teams/chi/2020.htm
# Scraping https://www.pro-football-reference.com/teams/ram/2020.htm
# Scraping https://www.pro-football-reference.com/teams/cle/2020.htm
# Scraping https://www.pro-football-reference.com/teams/mia/2020.htm
# Scraping https://www.pro-football-reference.com/teams/rav/2020.htm
# Scraping https://www.pro-football-reference.com/teams/oti/2020.htm
# Scraping https://www.pro-football-reference.com/teams/tam/2020.htm
# Scraping https://www.pro-football-reference.com/teams/nyj/2020.htm
# Scraping https://www.pro-football-reference.com/teams/pit/2020.htm
# Scraping https://www.pro-football-reference.com/teams/nor/2020.htm
# Scraping https://www.pro-football-reference.com/teams/buf/2020.htm
# Scraping https://www.pro-football-reference.com/teams/gnb/2020.htm
# Scraping https://www.pro-football-reference.com/teams/kan/2020.htm
#     ID  Position Drafted        Team  Draft Year  Pick Number  Team PF  \
# 0    0               NaN     Jaguars        2021            1    292.0
# 1    1               NaN        Jets        2021            2    229.0
# 2    2               NaN    Dolphins        2021            3    378.0
# 3    3               NaN     Falcons        2021            4    369.0
# 4    4               NaN     Bengals        2021            5    308.0
# 5    5               NaN      Eagles        2021            6    320.0
# 6    6               NaN       Lions        2021            7    342.0
# 7    7               NaN      Giants        2021            8    257.0
# 8    8               NaN    Panthers        2021            9    343.0
# 9    9               NaN     Broncos        2021           10    292.0
# 10  10               NaN     Cowboys        2021           11    376.0
# 11  11               NaN    Chargers        2021           12    346.0
# 12  12               NaN     Vikings        2021           13    393.0
# 13  13               NaN    Patriots        2021           14    298.0
# 14  14               NaN       49ers        2021           15    353.0
# 15  15               NaN     Raiders        2021           16    402.0
# 16  16               NaN   Cardinals        2021           17    403.0
# 17  17               NaN       Colts        2021           18    423.0
# 18  18               NaN    Redskins        2021           19    315.0
# 19  19               NaN       Bears        2021           20    356.0
# 20  20               NaN        Rams        2021           21    354.0
# 21  21               NaN      Browns        2021           22    384.0
# 22  22               NaN    Dolphins        2021           23    378.0
# 23  23               NaN      Ravens        2021           24    430.0
# 24  24               NaN      Titans        2021           25    450.0
# 25  25               NaN  Buccaneers        2021           26    448.0
# 26  26               NaN        Jets        2021           27    229.0
# 27  27               NaN    Steelers        2021           28    394.0
# 28  28               NaN      Saints        2021           29    449.0
# 29  29               NaN       Bills        2021           30    445.0
# 30  30               NaN     Packers        2021           31    474.0
# 31  31               NaN      Chiefs        2021           32    452.0
#
#     Team TO  Team Att  Team Yds.1  Team TD  ...  Opp. Y/A  Opp. 1stD.2  \
# 0      24.0     574.0      3469.0     23.0  ...       4.5        128.0
# 1      17.0     465.0      2557.0     15.0  ...       3.9         93.0
# 2      16.0     500.0      3352.0     23.0  ...       4.6        109.0
# 3      16.0     584.0      4105.0     25.0  ...       4.4         92.0
# 4      22.0     560.0      3400.0     19.0  ...       4.8        107.0
# 5      26.0     565.0      3229.0     22.0  ...       4.2         92.0
# 6      19.0     551.0      3816.0     24.0  ...       4.5        119.0
# 7      20.0     492.0      2815.0     10.0  ...       4.1        107.0
# 8      16.0     513.0      3642.0     16.0  ...       4.7        105.0
# 9      32.0     515.0      3127.0     19.0  ...       4.8         98.0
# 10     25.0     592.0      3962.0     25.0  ...       5.0        136.0
# 11     16.0     596.0      4048.0     28.0  ...       4.6        108.0
# 12     23.0     476.0      3626.0     32.0  ...       4.5        127.0
# 13     19.0     409.0      2652.0      8.0  ...       4.5        124.0
# 14     30.0     533.0      3791.0     24.0  ...       3.9         93.0
# 15     22.0     513.0      3858.0     26.0  ...       4.7        109.0
# 16     20.0     548.0      3750.0     26.0  ...       4.7        111.0
# 17     14.0     525.0      3889.0     23.0  ...       3.7         91.0
# 18     25.0     569.0      3320.0     14.0  ...       4.2         93.0
# 19     20.0     572.0      3407.0     26.0  ...       4.1        101.0
# 20     23.0     552.0      3791.0     20.0  ...       3.8         87.0
# 21     16.0     474.0      3373.0     26.0  ...       4.3        111.0
# 22     16.0     500.0      3352.0     23.0  ...       4.6        109.0
# 23     17.0     387.0      2618.0     24.0  ...       4.4         89.0
# 24     11.0     458.0      3449.0     32.0  ...       4.5        107.0
# 25     16.0     585.0      4235.0     38.0  ...       3.5         72.0
# 26     17.0     465.0      2557.0     15.0  ...       3.9         93.0
# 27     17.0     612.0      3694.0     33.0  ...       4.2         86.0
# 28     17.0     490.0      3567.0     25.0  ...       3.9         78.0
# 29     20.0     558.0      4243.0     36.0  ...       4.7        120.0
# 30     10.0     502.0      3869.0     44.0  ...       4.6        110.0
# 31     15.0     598.0      4637.0     38.0  ...       4.6        103.0
#
#     Off. Rank PF  Off. Rank Yds.1  Off. Rank TO  Off. Rank Att  Def. Rank PF  \
# 0           29.0             20.0          27.0            7.0          31.0
# 1           32.0             32.0          11.0           29.0          27.0
# 2           15.0             25.0           5.0           24.0           1.0
# 3           17.0              5.0           5.0            6.0          19.0
# 4           27.0             23.0          23.0           11.0          20.0
# 5           25.0             27.0          30.0           10.0          22.0
# 6           24.0             11.0          17.0           14.0          32.0
# 7           31.0             29.0          19.0           25.0          10.0
# 8           23.0             17.0           5.0           20.0          18.0
# 9           29.0             28.0          32.0           19.0          25.0
# 10          16.0              7.0          28.0            4.0          30.0
# 11          21.0              6.0           5.0            3.0          24.0
# 12          13.0             18.0          25.0           27.0          28.0
# 13          28.0             30.0          17.0           31.0          11.0
# 14          20.0             12.0          31.0           16.0          17.0
# 15          11.0             10.0          23.0           20.0          29.0
# 16          10.0             15.0          19.0           15.0          14.0
# 17           9.0              8.0           3.0           18.0          12.0
# 18          26.0             26.0          28.0            9.0           5.0
# 19          18.0             22.0          19.0            8.0           9.0
# 20          19.0             12.0          25.0           13.0           3.0
# 21          14.0             24.0           5.0           28.0          21.0
# 22          15.0             25.0           5.0           24.0           1.0
# 23           8.0             31.0          11.0           32.0           4.0
# 24           3.0             21.0           2.0           30.0          23.0
# 25           5.0              3.0           5.0            5.0           7.0
# 26          32.0             32.0          11.0           29.0          27.0
# 27          12.0             16.0          11.0            1.0           2.0
# 28           4.0             19.0          11.0           26.0           8.0
# 29           6.0              2.0          19.0           12.0          14.0
# 30           1.0              9.0           1.0           23.0          16.0
# 31           2.0              1.0           4.0            2.0           6.0
#
#     Def. Rank Yds.1  Def. Rank TO  Def. Rank Att
# 0              27.0          26.0            8.0
# 1              29.0          21.0           28.0
# 2              19.0           1.0            9.0
# 3              31.0          14.0           30.0
# 4              23.0          26.0           18.0
# 5              20.0          24.0            5.0
# 6              30.0          30.0           14.0
# 7              16.0           9.0           21.0
# 8              17.0           5.0           26.0
# 9              12.0          30.0           22.0
# 10             11.0           9.0            2.0
# 11              9.0          23.0           11.0
# 12             24.0          14.0           10.0
# 13              7.0          14.0            1.0
# 14              4.0          14.0            7.0
# 15             25.0          29.0           24.0
# 16             10.0          21.0           23.0
# 17             18.0           3.0           15.0
# 18              3.0          14.0            4.0
# 19             13.0          24.0           19.0
# 20              1.0           9.0           17.0
# 21             20.0          14.0           25.0
# 22             19.0           1.0            9.0
# 23             14.0          14.0           29.0
# 24             28.0           5.0           31.0
# 25             22.0           4.0           27.0
# 26             29.0          21.0           28.0
# 27              2.0           1.0            6.0
# 28              5.0           9.0           15.0
# 29              8.0           5.0           12.0
# 30              6.0          26.0            3.0
# 31             15.0           5.0           20.0
#
# [32 rows x 35 columns]

# %%
train_df_2 = pd.read_csv('Clean Reference For Last ' + str(YEARS) + ' Drafts.csv', encoding = 'utf-8')
train_df_2['ID'] = train_df_2['ID'] + 32
train_df_2
# Out:
#       ID Position Drafted      Team  Draft Year  Pick Number  Team PF  \
# 0     32               QB   Bengals        2020            1    279.0
# 1     33               DE  Redskins        2020            2    266.0
# 2     34               DB     Lions        2020            3    341.0
# 3     35                T    Giants        2020            4    341.0
# 4     36               QB  Dolphins        2020            5    306.0
# ..   ...              ...       ...         ...          ...      ...
# 631  663               RB   Vikings        2001           27    397.0
# 632  664               DB   Raiders        2001           28    479.0
# 633  665               DE      Rams        2001           29    540.0
# 634  666               WR     Colts        2001           30    429.0
# 635  667               TE    Ravens        2001           31    333.0
#
#      Team TO  Team Att  Team Yds.1  Team TD  ...  Opp. Y/A  Opp. 1stD.2  \
# 0       30.0     616.0      3652.0     18.0  ...       4.7        124.0
# 1       21.0     479.0      2812.0     18.0  ...       4.7        120.0
# 2       23.0     571.0      3900.0     28.0  ...       4.1         94.0
# 3       33.0     607.0      3731.0     30.0  ...       3.9        100.0
# 4       26.0     615.0      3804.0     22.0  ...       4.5        113.0
# ..       ...       ...         ...      ...  ...       ...          ...
# 631     28.0     495.0      3832.0     33.0  ...       4.5        110.0
# 632     20.0     475.0      3306.0     28.0  ...       4.0         85.0
# 633     35.0     587.0      5232.0     37.0  ...       4.4         95.0
# 634     29.0     571.0      4282.0     33.0  ...       4.3        109.0
# 635     26.0     504.0      2815.0     20.0  ...       2.7         59.0
#
#      Off. Rank PF  Off. Rank Yds.1  Off. Rank TO  Off. Rank Att  Def. Rank PF  \
# 0            30.0             19.0          27.0            6.0          25.0
# 1            32.0             32.0          16.0           28.0          27.0
# 2            18.0             10.0          19.0           17.0          26.0
# 3            18.0             18.0          30.0            9.0          30.0
# 4            25.0             12.0          25.0            7.0          32.0
# ..            ...              ...           ...            ...           ...
# 631           5.0              7.0          13.0           23.0          24.0
# 632           3.0             15.0           2.0           25.0           9.0
# 633           1.0              1.0          24.0            3.0          31.0
# 634           4.0              2.0          15.0            8.0          15.0
# 635          14.0             22.0           9.0           20.0           1.0
#
#      Def. Rank Yds.1  Def. Rank TO  Def. Rank Att
# 0               21.0          28.0            2.0
# 1               18.0          15.0           11.0
# 2               32.0          24.0           31.0
# 3               28.0          28.0           17.0
# 4               26.0          28.0           14.0
# ..               ...           ...            ...
# 631             28.0          31.0           28.0
# 632             25.0           7.0           30.0
# 633             27.0          20.0           17.0
# 634             18.0          25.0           14.0
# 635              8.0           1.0           13.0
#
# [636 rows x 35 columns]

# %%
reference_df2 = pd.concat([test_df_2, train_df_2])
reference_df2 = reference_df2.reset_index(drop=True)
reference_df2
# Out:
#       ID Position Drafted      Team  Draft Year  Pick Number  Team PF  \
# 0      0              NaN   Jaguars        2021            1    292.0
# 1      1              NaN      Jets        2021            2    229.0
# 2      2              NaN  Dolphins        2021            3    378.0
# 3      3              NaN   Falcons        2021            4    369.0
# 4      4              NaN   Bengals        2021            5    308.0
# ..   ...              ...       ...         ...          ...      ...
# 663  663               RB   Vikings        2001           27    397.0
# 664  664               DB   Raiders        2001           28    479.0
# 665  665               DE      Rams        2001           29    540.0
# 666  666               WR     Colts        2001           30    429.0
# 667  667               TE    Ravens        2001           31    333.0
#
#      Team TO  Team Att  Team Yds.1  Team TD  ...  Opp. Y/A  Opp. 1stD.2  \
# 0       24.0     574.0      3469.0     23.0  ...       4.5        128.0
# 1       17.0     465.0      2557.0     15.0  ...       3.9         93.0
# 2       16.0     500.0      3352.0     23.0  ...       4.6        109.0
# 3       16.0     584.0      4105.0     25.0  ...       4.4         92.0
# 4       22.0     560.0      3400.0     19.0  ...       4.8        107.0
# ..       ...       ...         ...      ...  ...       ...          ...
# 663     28.0     495.0      3832.0     33.0  ...       4.5        110.0
# 664     20.0     475.0      3306.0     28.0  ...       4.0         85.0
# 665     35.0     587.0      5232.0     37.0  ...       4.4         95.0
# 666     29.0     571.0      4282.0     33.0  ...       4.3        109.0
# 667     26.0     504.0      2815.0     20.0  ...       2.7         59.0
#
#      Off. Rank PF  Off. Rank Yds.1  Off. Rank TO  Off. Rank Att  Def. Rank PF  \
# 0            29.0             20.0          27.0            7.0          31.0
# 1            32.0             32.0          11.0           29.0          27.0
# 2            15.0             25.0           5.0           24.0           1.0
# 3            17.0              5.0           5.0            6.0          19.0
# 4            27.0             23.0          23.0           11.0          20.0
# ..            ...              ...           ...            ...           ...
# 663           5.0              7.0          13.0           23.0          24.0
# 664           3.0             15.0           2.0           25.0           9.0
# 665           1.0              1.0          24.0            3.0          31.0
# 666           4.0              2.0          15.0            8.0          15.0
# 667          14.0             22.0           9.0           20.0           1.0
#
#      Def. Rank Yds.1  Def. Rank TO  Def. Rank Att
# 0               27.0          26.0            8.0
# 1               29.0          21.0           28.0
# 2               19.0           1.0            9.0
# 3               31.0          14.0           30.0
# 4               23.0          26.0           18.0
# ..               ...           ...            ...
# 663             28.0          31.0           28.0
# 664             25.0           7.0           30.0
# 665             27.0          20.0           17.0
# 666             18.0          25.0           14.0
# 667              8.0           1.0           13.0
#
# [668 rows x 35 columns]

# %%
train_df_2 = train_df_2.drop(columns=['Position Drafted', 'Team', 'Draft Year'])
test_df_2  = test_df_2.drop(columns=['Position Drafted', 'Team', 'Draft Year'])
train_df_2.to_csv('Train Data For ' + str(CURRENT_YEAR+1) + ' Draft.csv', encoding = 'utf-8-sig', index=False)
test_df_2.to_csv('Test Data For ' + str(CURRENT_YEAR+1) + ' Draft.csv', encoding = 'utf-8-sig', index=False)
train_df_2
# Out:
#       ID  Pick Number  Team PF  Team TO  Team Att  Team Yds.1  Team TD  \
# 0     32            1    279.0     30.0     616.0      3652.0     18.0
# 1     33            2    266.0     21.0     479.0      2812.0     18.0
# 2     34            3    341.0     23.0     571.0      3900.0     28.0
# 3     35            4    341.0     33.0     607.0      3731.0     30.0
# 4     36            5    306.0     26.0     615.0      3804.0     22.0
# ..   ...          ...      ...      ...       ...         ...      ...
# 631  663           27    397.0     28.0     495.0      3832.0     33.0
# 632  664           28    479.0     20.0     475.0      3306.0     28.0
# 633  665           29    540.0     35.0     587.0      5232.0     37.0
# 634  666           30    429.0     29.0     571.0      4282.0     33.0
# 635  667           31    333.0     26.0     504.0      2815.0     20.0
#
#      Team Int  Team Att.1  Team Yds.2  ...  Opp. Y/A  Opp. 1stD.2  \
# 0        16.0       385.0      1517.0  ...       4.7        124.0
# 1        13.0       356.0      1583.0  ...       4.7        120.0
# 2        15.0       407.0      1649.0  ...       4.1         94.0
# 3        17.0       362.0      1685.0  ...       3.9        100.0
# 4        18.0       349.0      1156.0  ...       4.5        113.0
# ..        ...         ...         ...  ...       ...          ...
# 631      18.0       428.0      2129.0  ...       4.5        110.0
# 632      11.0       520.0      2470.0  ...       4.0         85.0
# 633      23.0       383.0      1843.0  ...       4.4         95.0
# 634      15.0       435.0      1859.0  ...       4.3        109.0
# 635      19.0       511.0      2199.0  ...       2.7         59.0
#
#      Off. Rank PF  Off. Rank Yds.1  Off. Rank TO  Off. Rank Att  Def. Rank PF  \
# 0            30.0             19.0          27.0            6.0          25.0
# 1            32.0             32.0          16.0           28.0          27.0
# 2            18.0             10.0          19.0           17.0          26.0
# 3            18.0             18.0          30.0            9.0          30.0
# 4            25.0             12.0          25.0            7.0          32.0
# ..            ...              ...           ...            ...           ...
# 631           5.0              7.0          13.0           23.0          24.0
# 632           3.0             15.0           2.0           25.0           9.0
# 633           1.0              1.0          24.0            3.0          31.0
# 634           4.0              2.0          15.0            8.0          15.0
# 635          14.0             22.0           9.0           20.0           1.0
#
#      Def. Rank Yds.1  Def. Rank TO  Def. Rank Att
# 0               21.0          28.0            2.0
# 1               18.0          15.0           11.0
# 2               32.0          24.0           31.0
# 3               28.0          28.0           17.0
# 4               26.0          28.0           14.0
# ..               ...           ...            ...
# 631             28.0          31.0           28.0
# 632             25.0           7.0           30.0
# 633             27.0          20.0           17.0
# 634             18.0          25.0           14.0
# 635              8.0           1.0           13.0
#
# [636 rows x 32 columns]

# %%
model_ready_combine2 = ready_dataset_for_modeling(train_df_2, test_df_2)
train_dataset_2 = model_ready_combine2[0]
test_dataset_2 = model_ready_combine2[1]

# %%
PICK_NUM2 = 12
test2 = prediction_data(train_dataset_2, test_dataset_2, PICK_NUM2-1, reference_df2)
test2
# Out:
#     ID  Distance Unit Position Drafted      Team  Draft Year  Pick Number  \
# 0   11      0.00  NaN              NaN  Chargers        2021           12
# 1  331      3.34  DEF               DT     Lions        2011           13
# 2  162      3.48  DEF               DE  Chargers        2016            3
# 3  237      3.62  DEF               LB  Steelers        2014           15
# 4  266      3.64  DEF               DB   Raiders        2013           12
# 5  586      3.74  DEF               DT  Patriots        2003           13
#
#    Team PF  Team TO  Team Att  ...  Opp. Y/A  Opp. 1stD.2  Off. Rank PF  \
# 0    346.0     16.0     596.0  ...       4.6        108.0          21.0
# 1    362.0     25.0     633.0  ...       4.5         98.0          15.0
# 2    320.0     24.0     667.0  ...       4.8        101.0          26.0
# 3    379.0     24.0     586.0  ...       4.3        106.0          16.0
# 4    290.0     26.0     629.0  ...       4.3         95.0          26.0
# 5    381.0     24.0     605.0  ...       4.7        129.0          10.0
#
#    Off. Rank Yds.1  Off. Rank TO  Off. Rank Att  Def. Rank PF  \
# 0              6.0           5.0            3.0          24.0
# 1             12.0          12.0            3.0          19.0
# 2              4.0          17.0            2.0          21.0
# 3             12.0          14.0           13.0          14.0
# 4              8.0          17.0            5.0          28.0
# 5             12.0           7.0            4.0          17.0
#
#    Def. Rank Yds.1  Def. Rank TO  Def. Rank Att
# 0              9.0          23.0           11.0
# 1             16.0          11.0           10.0
# 2             14.0          24.0            3.0
# 3              9.0          27.0           18.0
# 4             20.0          26.0            7.0
# 5             11.0          14.0           12.0
#
# [6 rows x 37 columns]

# %%
unit_prediction(train_dataset_2, test_dataset_2, PICK_NUM2-1, reference_df2)
# Out:
# {'OFF': 0, 'DEF': 100.0, 'Predicted': 'DEF', 'Actual': 'NA'}

# %%
test_unit_prediction(train_dataset_2, test_dataset_2, reference_df2)
# Out:
# 2021
# {'OFF': 80.0, 'DEF': 20.0, 'Predicted': 'OFF', 'Actual': 'NA'} Total 0/1
# {'OFF': 80.0, 'DEF': 20.0, 'Predicted': 'OFF', 'Actual': 'NA'} Total 0/2
# {'OFF': 80.0, 'DEF': 20.0, 'Predicted': 'OFF', 'Actual': 'NA'} Total 0/3
# {'OFF': 20.0, 'DEF': 80.0, 'Predicted': 'DEF', 'Actual': 'NA'} Total 0/4
# {'OFF': 80.0, 'DEF': 20.0, 'Predicted': 'OFF', 'Actual': 'NA'} Total 0/5
# {'OFF': 60.0, 'DEF': 40.0, 'Predicted': 'OFF', 'Actual': 'NA'} Total 0/6
# {'OFF': 60.0, 'DEF': 40.0, 'Predicted': 'OFF', 'Actual': 'NA'} Total 0/7
# {'OFF': 60.0, 'DEF': 40.0, 'Predicted': 'OFF', 'Actual': 'NA'} Total 0/8
# {'OFF': 40.0, 'DEF': 60.0, 'Predicted': 'DEF', 'Actual': 'NA'} Total 0/9
# {'OFF': 100.0, 'DEF': 0, 'Predicted': 'OFF', 'Actual': 'NA'} Total 0/10
# {'OFF': 20.0, 'DEF': 80.0, 'Predicted': 'DEF', 'Actual': 'NA'} Total 0/11
# {'OFF': 0, 'DEF': 100.0, 'Predicted': 'DEF', 'Actual': 'NA'} Total 0/12
# {'OFF': 20.0, 'DEF': 80.0, 'Predicted': 'DEF', 'Actual': 'NA'} Total 0/13
# {'OFF': 60.0, 'DEF': 40.0, 'Predicted': 'OFF', 'Actual': 'NA'} Total 0/14
# {'OFF': 60.0, 'DEF': 40.0, 'Predicted': 'OFF', 'Actual': 'NA'} Total 0/15
# {'OFF': 40.0, 'DEF': 60.0, 'Predicted': 'DEF', 'Actual': 'NA'} Total 0/16
# {'OFF': 20.0, 'DEF': 80.0, 'Predicted': 'DEF', 'Actual': 'NA'} Total 0/17
# {'OFF': 0, 'DEF': 100.0, 'Predicted': 'DEF', 'Actual': 'NA'} Total 0/18
# {'OFF': 40.0, 'DEF': 60.0, 'Predicted': 'DEF', 'Actual': 'NA'} Total 0/19
# {'OFF': 80.0, 'DEF': 20.0, 'Predicted': 'OFF', 'Actual': 'NA'} Total 0/20
# {'OFF': 60.0, 'DEF': 40.0, 'Predicted': 'OFF', 'Actual': 'NA'} Total 0/21
# {'OFF': 0, 'DEF': 100.0, 'Predicted': 'DEF', 'Actual': 'NA'} Total 0/22
# {'OFF': 80.0, 'DEF': 20.0, 'Predicted': 'OFF', 'Actual': 'NA'} Total 0/23
# {'OFF': 40.0, 'DEF': 60.0, 'Predicted': 'DEF', 'Actual': 'NA'} Total 0/24
# {'OFF': 40.0, 'DEF': 60.0, 'Predicted': 'DEF', 'Actual': 'NA'} Total 0/25
# {'OFF': 20.0, 'DEF': 80.0, 'Predicted': 'DEF', 'Actual': 'NA'} Total 0/26
# {'OFF': 40.0, 'DEF': 60.0, 'Predicted': 'DEF', 'Actual': 'NA'} Total 0/27
# {'OFF': 80.0, 'DEF': 20.0, 'Predicted': 'OFF', 'Actual': 'NA'} Total 0/28
# {'OFF': 20.0, 'DEF': 80.0, 'Predicted': 'DEF', 'Actual': 'NA'} Total 0/29
# {'OFF': 20.0, 'DEF': 80.0, 'Predicted': 'DEF', 'Actual': 'NA'} Total 0/30
# {'OFF': 20.0, 'DEF': 80.0, 'Predicted': 'DEF', 'Actual': 'NA'} Total 0/31
# {'OFF': 0, 'DEF': 100.0, 'Predicted': 'DEF', 'Actual': 'NA'} Total 0/32
#
# Correct Predictions %:  0.0
# Correct 80+% Predictions %:  0.0
# (0.0, 0.0)
